# %% [markdown]
# # Exercise on n-gram language models

# %% [markdown]
# Students:
#
# Dimopoulos Vasileios, Christos Katrinakis, Giannis Trantalidis

# %%
import nltk
nltk.download('punkt')
nltk.download('webtext')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vassi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package webtext to
# [nltk_data]     C:\Users\vassi\AppData\Roaming\nltk_data...
# [nltk_data]   Package webtext is already up-to-date!
# True

# %% [markdown]
# For the purpose of this exercise we used a corpus from the NLTK corpus library, named "Web Text" including web text and messages from the Firefox discussion forums. As we see below, this corpus includes 25733 sentences and comes in a form of tokenized sentences, using webtext.sents().

# %%
from nltk.corpus import webtext
len(webtext.sents())
# Out:
# 25733

# %%
webtext.raw()
# Out:
# 'Cookie Manager: "Don\'t allow sites that set removed cookies to set future cookies" should stay checked\r\nWhen in full screen mode\r\nPressing Ctrl-N should open a new browser when only download dialog is left open\r\nadd icons to context menu\r\nSo called "tab bar" should be made a proper toolbar or given the ability collapse / expand.\r\n[XUL] Implement Cocoa-style toolbar customization.\r\n#ifdefs for MOZ_PHOENIX\r\ncustomize dialog\'s toolbar has small icons when small icons is not checked\r\nnightly builds and tinderboxen for Phoenix\r\nfinish tearing prefs UI to pieces and then make it not suck\r\n"mozbrowser" script doesn\'t start correct binary\r\nNeed bookmark groups icon\r\nDropping at top of palette box horks things\r\nkeyboard shortcut for Increase Text Size is broken\r\ndefault phoenix bookmarks\r\n[cust] need a toolbar spacer and spring spacer for customize\r\nCan\'t launch phoenix while Mozilla is running (or vice versa)\r\nseparator not available when all toolbar items are in toolbar layout\r\nhistory menu for the back buttons doesn\'t work\r\nattempting to open "back button history menu" in the second window generates another back button on the toolbar\r\nPhoenix and Mozilla cannot comfortably share a source tree\r\nPhoenix forgets all cookies even though "Enable cookies for the current session only" is NOT chosen\r\nStarting Customizing Toolbar makes the current page go blank\r\nCheck in Satchel (the successor to wallet)\r\nMousing over back menu in second window horks things\r\nPersonal toolbar needs a min-height to avoid "popping in"\r\nNew Folder...in ptoolbar context menu is broken\r\nImplement Mozilla Firebird Help\r\ntabs close in the wrong order (right to left)\r\nback buttons and context options always disabled.\r\nCustomising toolbar breaks the throbber!\r\nmanage bookmarks causes hang\r\nland pch\'s bookmarks patch from bug 160019\r\nPreferences > Privacy > Images == Wonky\r\nExtremely high memory consumption after closing all windows with Quick Launch (Turbo) enabled\r\nGo menu needs to have an id=\r\nimplement progress meter in URLbar\r\nview source tries to download type application x-view-source from view-source:<url>\r\nsecond window opens mozilla\r\nfix branding\r\nauto close for download manager would be nice\r\nComponents of the Navigation Toolbar do not appear with the Modern theme.\r\nPop up window blocking\r\nUabar doesn\'t work\r\nTheme changes will take effect when you restart _Mozilla_.\r\nNeed large icons for the Options menu\r\nEnable images cannot be used to disable the display of images.\r\nThe bookmark tree jumps unexpectedly to the bottom of its view when the the first visible row is not the first one\r\nMove bookmarks transactions into a JS service (adding a bookmark leaks the Add Bookmark dialog)\r\nShortcut Ctrl-Y (redo) does not work in Bookmarks Manager\r\nEradicate AddBookmarkImmediately\r\nDeleting a selection should select the next item\r\ntransaction manager does not handle import\r\ncustomize toolbar clears URL\r\n3.2% increase in Phoenix Ts after bookmark landing\r\ncannot close folder with single click on twistie\r\nPref UI to specify a proxy server for web navigation\r\nImplement improved\r\nImplement global Go menu\r\nReadd Open Location\r\nNeed tab loading icon\r\nfirst Mozilla Firefox window ignored by nsIWindowMediator\r\nfirst Phoenix window ignored by nsIWindowMediator\r\npreferences no longer works\r\nOpen Personal Toolbar folder in toolbar\r\nweb search for "" in context menu don\'t work\r\nFix full screen to have smaller icons\r\nPort patch to bug 164006 (wyciwyg: in tab titles)\r\n[cust] Add more off-by-default toolbar buttons\r\ntextmode buttons need hover state\r\nenable nsITheme form control goodness for Phoenix\r\nrename executable and profile dir\r\nNeed to enable wallet (password manager manager manager)\r\nNew Extension Manager\r\nthe changes to mozbrowser too confusing and too much\r\nMissing proxy image\r\nCannot File > New Bookmark while managin ...

# %%
sentences = webtext.sents()

# %%
for sent in sentences[:10]:
    print(sent)
    print("_________________")
# Out:
# ['Cookie', 'Manager', ':', '"', 'Don', "'", 't', 'allow', 'sites', 'that', 'set', 'removed', 'cookies', 'to', 'set', 'future', 'cookies', '"', 'should', 'stay', 'checked', 'When', 'in', 'full', 'screen', 'mode', 'Pressing', 'Ctrl', '-', 'N', 'should', 'open', 'a', 'new', 'browser', 'when', 'only', 'download', 'dialog', 'is', 'left', 'open', 'add', 'icons', 'to', 'context', 'menu', 'So', 'called', '"', 'tab', 'bar', '"', 'should', 'be', 'made', 'a', 'proper', 'toolbar', 'or', 'given', 'the', 'ability', 'collapse', '/', 'expand', '.']
# _________________
# ['[', 'XUL', ']', 'Implement', 'Cocoa', '-', 'style', 'toolbar', 'customization', '.']
# _________________
# ['#', 'ifdefs', 'for', 'MOZ_PHOENIX', 'customize', 'dialog', "'", 's', 'toolbar', 'has', 'small', 'icons', 'when', 'small', 'icons', 'is', 'not', 'checked', 'nightly', 'builds', 'and', 'tinderboxen', 'for', 'Phoenix', 'finish', 'tearing', 'prefs', 'UI', 'to', 'pieces', 'and', 'then', 'make', 'it', 'not', 'suck', '"', 'mozbrowser', '"', 'script', 'doesn', "'", 't', 'start', 'correct', 'binary', 'Need', 'bookmark', 'groups', 'icon', 'Dropping', 'at', 'top', 'of', 'palette', 'box', 'horks', 'things', 'keyboard', 'shortcut', 'for', 'Increase', 'Text', 'Size', 'is', 'broken', 'default', 'phoenix', 'bookmarks', '[', 'cust', ']', 'need', 'a', 'toolbar', 'spacer', 'and', 'spring', 'spacer', 'for', 'customize', 'Can', "'", 't', 'launch', 'phoenix', 'while', 'Mozilla', 'is', 'running', '(', 'or', 'vice', 'versa', ')', 'separator', 'not', 'available', 'when', 'all', 'toolbar', 'items', 'are', 'in', 'toolbar', 'layout', 'history', 'menu', 'for', 'the', 'back', 'buttons', 'doesn', "'", 't', 'work', 'attempting', 'to', 'open', '"', 'back', 'button', 'history', 'menu', '"', 'in', 'the', 'second', 'window', 'generates', 'another', 'back', 'button', 'on', 'the', 'toolbar', 'Phoenix', 'and', 'Mozilla', 'cannot', 'comfortably', 'share', 'a', 'source', 'tree', 'Phoenix', 'forgets', 'all', 'cookies', 'even', 'though', '"', 'Enable', 'cookies', 'for', 'the', 'current', 'session', 'only', '"', 'is', 'NOT', 'chosen', 'Starting', 'Customizing', 'Toolbar', 'makes', 'the', 'current', 'page', 'go', 'blank', 'Check', 'in', 'Satchel', '(', 'the', 'successor', 'to', 'wallet', ')', 'Mousing', 'over', 'back', 'menu', 'in', 'second', 'window', 'horks', 'things', 'Personal', 'toolbar', 'needs', 'a', 'min', '-', 'height', 'to', 'avoid', '"', 'popping', 'in', '"', 'New', 'Folder', '...', 'in', 'ptoolbar', 'context', 'menu', 'is', 'broken', 'Implement', 'Mozilla', 'Firebird', 'Help', 'tabs', 'close', 'in', 'the', 'wrong', 'order', '(', 'right', 'to', 'left', ')', 'back', 'buttons', 'and', 'context', 'options', 'always', 'disabled', '.']
# _________________
# ['Customising', 'toolbar', 'breaks', 'the', 'throbber', '!']
# _________________
# ['manage', 'bookmarks', 'causes', 'hang', 'land', 'pch', "'", 's', 'bookmarks', 'patch', 'from', 'bug', '160019', 'Preferences', '>', 'Privacy', '>', 'Images', '==', 'Wonky', 'Extremely', 'high', 'memory', 'consumption', 'after', 'closing', 'all', 'windows', 'with', 'Quick', 'Launch', '(', 'Turbo', ')', 'enabled', 'Go', 'menu', 'needs', 'to', 'have', 'an', 'id', '=', 'implement', 'progress', 'meter', 'in', 'URLbar', 'view', 'source', 'tries', 'to', 'download', 'type', 'application', 'x', '-', 'view', '-', 'source', 'from', 'view', '-', 'source', ':<', 'url', '>', 'second', 'window', 'opens', 'mozilla', 'fix', 'branding', 'auto', 'close', 'for', 'download', 'manager', 'would', 'be', 'nice', 'Components', 'of', 'the', 'Navigation', 'Toolbar', 'do', 'not', 'appear', 'with', 'the', 'Modern', 'theme', '.']
# _________________
# ['Pop', 'up', 'window', 'blocking', 'Uabar', 'doesn', "'", 't', 'work', 'Theme', 'changes', 'will', 'take', 'effect', 'when', 'you', 'restart', '_Mozilla_', '.']
# _________________
# ['Need', 'large', 'icons', 'for', 'the', 'Options', 'menu', 'Enable', 'images', 'cannot', 'be', 'used', 'to', 'disable', 'the', 'display', 'of', 'images', '.']
# _________________
# ['The', 'bookmark', 'tree', 'jumps', 'unexpectedly', 'to', 'the', 'bottom', 'of', 'its', 'view', 'when', 'the', 'the', 'first', 'visible', 'row', 'is', 'not', 'the', 'first', 'one', 'Move', 'bookmarks', 'transactions', 'into', 'a', 'JS', 'service', '(', 'adding', 'a', 'bookmark', 'leaks', 'the', 'Add', 'Bookmark', 'dialog', ')', 'Shortcut', 'Ctrl', '-', 'Y', '(', 'redo', ')', 'does', 'not', 'work', 'in', 'Bookmarks', 'Manager', 'Eradicate', 'AddBookmarkImmediately', 'Deleting', 'a', 'selection', 'should', 'select', 'the', 'next', 'item', 'transaction', 'manager', 'does', 'not', 'handle', 'import', 'customize', 'toolbar', 'clears', 'URL', '3', '.', '2', '%', 'increase', 'in', 'Phoenix', 'Ts', 'after', 'bookmark', 'landing', 'cannot', 'close', 'folder', 'with', 'single', 'click', 'on', 'twistie', 'Pref', 'UI', 'to', 'specify', 'a', 'proxy', 'server', 'for', 'web', 'navigation', 'Implement', 'improved', 'Implement', 'global', 'Go', 'menu', 'Readd', 'Open', 'Location', 'Need', 'tab', 'loading', 'icon', 'first', 'Mozilla', 'Firefox', 'window', 'ignored', 'by', 'nsIWindowMediator', 'first', 'Phoenix', 'window', 'ignored', 'by', 'nsIWindowMediator', 'preferences', 'no', 'longer', 'works', 'Open', 'Personal', 'Toolbar', 'folder', 'in', 'toolbar', 'web', 'search', 'for', '""', 'in', 'context', 'menu', 'don', "'", 't', 'work', 'Fix', 'full', 'screen', 'to', 'have', 'smaller', 'icons', 'Port', 'patch', 'to', 'bug', '164006', '(', 'wyciwyg', ':', 'in', 'tab', 'titles', ')', '[', 'cust', ']', 'Add', 'more', 'off', '-', 'by', '-', 'default', 'toolbar', 'buttons', 'textmode', 'buttons', 'need', 'hover', 'state', 'enable', 'nsITheme', 'form', 'control', 'goodness', 'for', 'Phoenix', 'rename', 'executable', 'and', 'profile', 'dir', 'Need', 'to', 'enable', 'wallet', '(', 'password', 'manager', 'manager', 'manager', ')', 'New', 'Extension', 'Manager', 'the', 'changes', 'to', 'mozbrowser', 'too', 'confusing', 'and', 'too', 'much', 'Missing', 'proxy', 'image', 'Cannot', 'File', '>', 'New', 'Bookmark', 'while', 'managing', 'a', 'new', 'folder', 'Bookmarks', 'are', 'not', 'loaded', 'if', 'the', 'Personal', 'Toolbar', 'is', 'switched', 'off', 'Pretty', 'up', 'dns', 'error', 'page', 'a', 'bit', 'middle', 'click', '(', 'pt', '+', 'bookmark', 'menu', ')', 'loads', 'in', 'the', 'current', 'tab', '+', 'new', 'tab', 'Nightly', 'for', '22', 'Sept', 'displays', 'page', 'details', 'above', 'window', 'Ctrl', '-', 'W', 'does', 'not', 'close', 'the', 'current', 'tab', 'listboxes', 'and', 'tree', 'views', 'don', "'", 't', 'support', 'themes', 'on', 'winxp', 'Ctrl', '+', 'Mousewheel', 'should', 'resize', 'text', 'bookmarks', 'should', 'import', 'Mozilla', "'", 's', 'bookmarks', 'Please', 'tell', 'people', 'to', 'use', 'a', 'new', 'profile', '.']
# _________________
# ['combine', 'links', '+', 'toolbar', 'File', '|', 'Import', '...', 'does', 'not', 'work', 'cannot', 'import', '4', '.', 'x', 'About', 'dialog', 'weirdness', 'Context', 'menu', 'doesn', "'", 't', 'appear', 'when', 'right', 'clicking', 'on', 'disabled', 'forward', 'or', 'back', 'can', "'", 't', 'specify', 'cookie', 'details', 'Proxy', 'settings', 'in', 'prefs', '.', 'js', 'seem', 'to', 'be', 'ignored', '...']
# _________________
# ['Incorrectly', 'renders', 'various', 'web', 'pages', 'Window', 'won', "'", 't', 'show', 'completely', 'Can', "'", 't', 'change', 'privacy', 'settings', '[', 'Moz', ']', 'Cannot', 'set', '"', 'Imported', 'IE', 'Favorites', '"', 'to', 'default', 'personal', 'toolbar', 'folder', 'pheonix', 'Need', 'smaller', 'throbber', 'to', 'use', 'with', 'small', 'icons', 'Blank', 'URL', 'bar', 'after', 'using', 'Customize', 'Toolbar', 'Mousewheel', 'does', 'not', 'scroll', 'web', 'page', 'ctrl', '+', 'tab', 'should', 'switch', 'tabs', 'in', 'browser', 'favicon', '.', 'ico', 'colors', 'render', 'improperly', 'in', 'tabs', 'and', 'URL', 'bar', '-', 'remote', 'openurl', '()', 'opens', 'Mozilla', 'window', 'if', 'Mozilla', 'is', 'running', 'make', 'preferences', 'resizable', 'Scroll', 'bar', 'becomes', 'blank', 'fix', 'addressbar', 'dropdown', 'icon', 'for', 'linux', '.']
# _________________

# %% [markdown]
# We split the total sentences into two sets, training and test, for the purpose of the models' training.

# %%
from sklearn.model_selection import train_test_split

split_ratio = 0.8
train_set, test_set = train_test_split(sentences, test_size=1 - split_ratio, random_state=42)

# %% [markdown]
# We can see below the most frequent words found in our corpus, sorted in a descending order.

# %%
from collections import Counter

flat_words = [word for sentence in train_set for word in sentence]
word_freq = Counter(flat_words)
for word, freq in word_freq.items():
    print(f"{word}: {freq} times")
# Out:
# ***: 402 times
# Very: 191 times
# fine: 111 times
# ,: 9850 times
# elegant: 42 times
# scented: 3 times
# balanced: 39 times
# .: 14194 times
# Mother: 65 times
# :: 11335 times
# No: 649 times
# way: 193 times
# ...: 1259 times
# She: 228 times
# is: 2327 times
# singing: 35 times
# into: 263 times
# the: 5843 times
# saw: 64 times
# ?: 3480 times
# Not: 179 times
# Rated: 37 times
# light: 29 times
# and: 3288 times
# delicate: 8 times
# -: 2660 times
# decent: 22 times
# but: 902 times
# a: 4630 times
# bit: 213 times
# attenuated: 1 times
# Rich: 23 times
# sweet: 45 times
# palate: 95 times
# Woman: 525 times
# #: 2987 times
# 1: 1834 times
# Omigod: 6 times
# !: 3256 times
# In: 81 times
# morning: 51 times
# 8: 104 times
# am: 182 times
# while: 190 times
# I: 6213 times
# ': 8632 times
# m: 933 times
# takin: 3 times
# shit: 242 times
# all: 680 times
# fuckin: 44 times
# day: 128 times
# Chick: 402 times
# Because: 55 times
# not: 1983 times
# in: 3382 times
# love: 127 times
# with: 1556 times
# him: 342 times
# Is: 116 times
# it: 2089 times
# Connecticut: 4 times
# Teen: 431 times
# girl: 965 times
# 2: 1368 times
# wish: 40 times
# had: 292 times
# Jeter: 2 times
# s: 2626 times
# so: 661 times
# hot: 90 times
# It: 629 times
# stupid: 46 times
# White: 109 times
# guy: 880 times
# on: 2594 times
# cell: 469 times
# You: 1025 times
# ain: 103 times
# t: 2819 times
# got: 319 times
# nowhere: 3 times
# to: 5062 times
# smoke: 24 times
# ?...: 77 times
# Something: 12 times
# Sparrow: 28 times
# keeps: 24 times
# his: 358 times
# person: 57 times
# at: 751 times
# times: 75 times
# That: 416 times
# too: 306 times
# many: 87 times
# different: 74 times
# spirits: 1 times
# *****: 39 times
# From: 22 times
# magnum: 2 times
# Girl: 1410 times
# funny: 29 times
# GIF: 7 times
# animation: 6 times
# speed: 14 times
# fast: 24 times
# Web: 55 times
# site: 139 times
# pop: 32 times
# up: 757 times
# blocked: 26 times
# by: 310 times
# Mozilla: 176 times
# blocker: 18 times
# FATHER: 47 times
# that: 1790 times
# Tourist: 158 times
# On: 43 times
# farm: 4 times
# manure: 1 times
# smells: 40 times
# pretty: 62 times
# good: 378 times
# Kid: 25 times
# behind: 56 times
# Fubu: 2 times
# jersey: 2 times
# Dad: 82 times
# who: 218 times
# Guy: 1323 times
# don: 866 times
# know: 801 times
# if: 712 times
# d: 212 times
# say: 193 times
# Green: 6 times
# tannins: 37 times
# dry: 101 times
# end: 66 times
# long: 158 times
# soft: 30 times
# pleasant: 25 times
# leathery: 2 times
# length: 48 times
# ll: 284 times
# let: 101 times
# you: 3609 times
# brush: 5 times
# mine: 16 times
# can: 769 times
# yours: 11 times
# Preppy: 3 times
# bad: 112 times
# Your: 44 times
# father: 41 times
# said: 174 times
# he: 704 times
# needed: 21 times
# stripper: 10 times
# remove: 55 times
# some: 409 times
# paint: 11 times
# Urlbar: 2 times
# autofill: 3 times
# matches: 8 times
# http: 92 times
# ://: 95 times
# prefix: 2 times
# Dom: 3 times
# inspector: 5 times
# reports: 13 times
# firefox: 203 times
# browser: 328 times
# window: 536 times
# as: 537 times
# ": 2067 times
# navagator: 1 times
# menu: 394 times
# Full: 20 times
# filename: 18 times
# of: 2532 times
# download: 251 times
# does: 585 times
# appear: 63 times
# when: 1303 times
# has: 335 times
# spaces: 13 times
# Back: 39 times
# Two: 26 times
# same: 121 times
# Polish: 8 times
# man: 422 times
# Her: 14 times
# 3: 125 times
# bedroom: 3 times
# apartment: 18 times
# Williamsburg: 1 times
# for: 1500 times
# 9: 136 times
# months: 16 times
# every: 81 times
# year: 101 times
# SCENE: 18 times
# [: 950 times
# wind: 9 times
# ]: 947 times
# clop: 27 times
# KING: 2 times
# ARTHUR: 190 times
# Whoa: 10 times
# there: 454 times
# Man: 409 times
# how: 235 times
# gonna: 172 times
# play: 42 times
# like: 1266 times
# kid: 82 times
# came: 44 times
# indeed: 8 times
# its: 101 times
# type: 85 times
# They: 190 times
# just: 747 times
# die: 38 times
# right: 369 times
# mother: 63 times
# Maybe: 54 times
# do: 671 times
# SOLDIER: 18 times
# ve: 224 times
# two: 182 times
# empty: 61 times
# halves: 3 times
# coconut: 14 times
# re: 647 times
# bangin: 2 times
# em: 30 times
# together: 39 times
# Queer: 162 times
# leave: 43 times
# my: 1051 times
# door: 45 times
# unlocked: 2 times
# Barrio: 1 times
# sue: 4 times
# MTA: 17 times
# stank: 3 times
# Oh: 522 times
# Men: 4 times
# Are: 103 times
# Mars: 2 times
# Women: 4 times
# Venus: 1 times
# Saturday: 7 times
# was: 978 times
# from: 813 times
# Hell: 14 times
# DENNIS: 19 times
# told: 87 times
# *: 209 times
# Slightly: 17 times
# flat: 17 times
# flavoursome: 4 times
# rustic: 13 times
# Yeah: 629 times
# ASPCA: 2 times
# remember: 91 times
# Mr: 14 times
# Millard: 1 times
# see: 254 times
# busy: 11 times
# bitch: 92 times
# black: 145 times
# Black: 168 times
# employee: 19 times
# sighing: 1 times
# people: 266 times
# See: 40 times
# crazy: 52 times
# thinkin: 2 times
# smashing: 2 times
# car: 61 times
# windows: 164 times
# must: 76 times
# have: 1058 times
# pulled: 12 times
# something: 203 times
# out: 588 times
# hat: 22 times
# get: 627 times
# here: 262 times
# We: 260 times
# California: 8 times
# Conductor: 86 times
# Next: 24 times
# stop: 119 times
# West: 8 times
# 4th: 3 times
# stand: 28 times
# clear: 54 times
# issue: 12 times
# will: 339 times
# feel: 94 times
# sting: 1 times
# be: 1049 times
# Bo: 2 times
# sun: 6 times
# hand: 61 times
# your: 755 times
# own: 56 times
# Gentile: 6 times
# Hey: 164 times
# better: 122 times
# than: 251 times
# reading: 23 times
# Bible: 14 times
# always: 160 times
# knew: 21 times
# they: 487 times
# were: 216 times
# penalties: 1 times
# paying: 9 times
# taxes: 1 times
# time: 338 times
# never: 168 times
# those: 107 times
# applied: 5 times
# me: 1052 times
# Little: 195 times
# boy: 331 times
# month: 14 times
# didn: 175 times
# walk: 50 times
# around: 111 times
# saying: 49 times
# Liquorice: 4 times
# cherry: 14 times
# fruit: 236 times
# want: 364 times
# one: 516 times
# says: 73 times
# we: 507 times
# adopt: 2 times
# avoid: 8 times
# messy: 1 times
# stuff: 68 times
# Ghetto: 77 times
# thug: 17 times
# touch: 138 times
# this: 961 times
# Do: 164 times
# figure: 16 times
# skating: 2 times
# short: 26 times
# program: 29 times
# serious: 21 times
# Dude: 225 times
# Young: 51 times
# woman: 279 times
# Where: 108 times
# did: 202 times
# these: 115 times
# cars: 14 times
# come: 147 times
# wanna: 71 times
# pregnant: 40 times
# ass: 117 times
# slim: 22 times
# build: 122 times
# Lady: 119 times
# sent: 18 times
# Hoover: 1 times
# When: 163 times
# really: 320 times
# someone: 102 times
# cheat: 2 times
# tell: 167 times
# Hay: 2 times
# la: 12 times
# paka: 1 times
# Will: 132 times
# backs: 3 times
# slowly: 11 times
# then: 287 times
# suddenly: 18 times
# draws: 5 times
# Elizabeth: 62 times
# sword: 24 times
# points: 25 times
# Jack: 214 times
# WILL: 109 times
# TURNER: 109 times
# keep: 74 times
# promises: 1 times
# make: 231 times
# If: 199 times
# nigga: 35 times
# eloquent: 3 times
# means: 33 times
# bullshit: 16 times
# A: 366 times
# sign: 31 times
# Jaboulet: 1 times
# losing: 4 times
# Old: 176 times
# What: 582 times
# Subway: 7 times
# rider: 4 times
# going: 362 times
# much: 172 times
# sales: 6 times
# pitch: 1 times
# BRIDGEKEEPER: 12 times
# quest: 11 times
# chick: 163 times
# quite: 179 times
# opposite: 6 times
# felt: 17 times
# trying: 138 times
# scrotum: 4 times
# stall: 5 times
# ....: 36 times
# believe: 74 times
# skin: 17 times
# And: 337 times
# sleep: 39 times
# naked: 18 times
# KFC: 2 times
# Attempting: 4 times
# drag: 50 times
# drop: 89 times
# Bookmark: 131 times
# Manager: 157 times
# freezes: 45 times
# Bird: 2 times
# Unexpected: 2 times
# Launch: 11 times
# or: 572 times
# Opening: 25 times
# item: 61 times
# double: 27 times
# clicking: 149 times
# scrollbar: 27 times
# history: 111 times
# sidebar: 89 times
# Non: 12 times
# clickable: 6 times
# link: 199 times
# try: 92 times
# connect: 5 times
# mozilla: 79 times
# firebird: 110 times
# Profile: 40 times
# starts: 32 times
# clicked: 44 times
# already: 94 times
# running: 73 times
# Application: 9 times
# amegaproxy: 1 times
# toolbar: 287 times
# no: 602 times
# longer: 59 times
# works: 60 times
# Can: 210 times
# go: 395 times
# any: 194 times
# URL: 240 times
# after: 455 times
# installing: 43 times
# flash: 36 times
# Wait: 77 times
# still: 171 times
# malaria: 3 times
# Good: 115 times
# Everything: 8 times
# only: 278 times
# off: 282 times
# now: 279 times
# FRENCH: 25 times
# GUARD: 45 times
# remain: 6 times
# gone: 33 times
# illegitimate: 1 times
# faced: 2 times
# bugger: 7 times
# folk: 2 times
# either: 43 times
# hate: 66 times
# Thinking: 1 times
# about: 444 times
# what: 506 times
# WHAT: 2 times
# DO: 2 times
# YOU: 8 times
# MEAN: 1 times
# ASK: 1 times
# SOMEONE: 1 times
# WHERE: 2 times
# THE: 5 times
# FUCKING: 2 times
# RIVER: 2 times
# IS: 1 times
# shall: 27 times
# feint: 1 times
# north: 8 times
# east: 5 times
# --: 335 times
# think: 378 times
# dumbass: 9 times
# AA: 2 times
# Alcoholics: 1 times
# Anonymous: 1 times
# Super: 2 times
# thin: 12 times
# model: 12 times
# /: 317 times
# actress: 2 times
# Urrgghhh: 1 times
# !!!: 5 times
# Shut: 34 times
# okay: 43 times
# ?": 47 times
# The: 453 times
# foot: 13 times
# cream: 22 times
# use: 184 times
# feet: 16 times
# stink: 3 times
# coffee: 15 times
# smell: 48 times
# because: 195 times
# spilled: 2 times
# carpet: 5 times
# cleaned: 2 times
# Pearl: 30 times
# asshole: 29 times
# Cabbie: 7 times
# WYVERN: 3 times
# Hidden: 1 times
# Four: 5 times
# fingered: 2 times
# Chinese: 52 times
# waitress: 4 times
# 10: 45 times
# minute: 18 times
# meant: 11 times
# shitting: 3 times
# spleen: 1 times
# old: 177 times
# Mommy: 27 times
# Aw: 17 times
# Lovely: 67 times
# acidity: 53 times
# Russian: 9 times
# should: 526 times
# introduce: 4 times
# sister: 44 times
# referring: 3 times
# Producers: 2 times
# made: 98 times
# fun: 58 times
# Hitler: 10 times
# positive: 5 times
# Goth: 7 times
# How: 140 times
# could: 202 times
# passed: 14 times
# very: 246 times
# weird: 34 times
# Have: 61 times
# nice: 165 times
# evening: 10 times
# medieval: 1 times
# hall: 1 times
# KNIGHTS: 29 times
# knights: 10 times
# round: 22 times
# table: 47 times
# even: 221 times
# mean: 251 times
# ".: 40 times
# ha: 121 times
# issues: 13 times
# food: 76 times
# Dry: 29 times
# finish: 82 times
# shakes: 4 times
# head: 85 times
# disappointment: 3 times
# walking: 38 times
# Asian: 87 times
# fucking: 179 times
# taught: 13 times
# martial: 1 times
# arts: 2 times
# _7nsQueryInterface: 1 times
# @@: 1 times
# 6B: 1 times
# @: 10 times
# located: 7 times
# pre: 9 times
# Mac: 42 times
# OS: 63 times
# X: 70 times
# 4: 58 times
# crash: 198 times
# i: 82 times
# hide: 18 times
# displays: 47 times
# popup: 91 times
# dialogue: 9 times
# (: 761 times
# sheet: 15 times
# ).: 43 times
# Customer: 18 times
# having: 67 times
# sex: 110 times
# myself: 50 times
# JACK: 152 times
# SPARROW: 152 times
# chest: 51 times
# unknown: 8 times
# size: 95 times
# origin: 1 times
# Yuppie: 29 times
# couldn: 34 times
# Father: 31 times
# Nature: 3 times
# caught: 11 times
# cheatin: 1 times
# mad: 33 times
# dropped: 11 times
# damn: 19 times
# snow: 10 times
# us: 127 times
# People: 19 times
# label: 16 times
# unlocks: 5 times
# small: 80 times
# key: 80 times
# square: 8 times
# security: 26 times
# bolts: 1 times
# protrude: 1 times
# opened: 101 times
# heart: 24 times
# inside: 51 times
# beating: 5 times
# crewmen: 10 times
# Flying: 20 times
# Dutchman: 21 times
# approach: 2 times
# tucks: 2 times
# vest: 4 times
# uses: 37 times
# swords: 5 times
# each: 53 times
# stab: 5 times
# backwards: 9 times
# kill: 75 times
# attacking: 1 times
# ISLA: 2 times
# CRUCES: 2 times
# beach: 19 times
# first: 172 times
# arrive: 3 times
# back: 310 times
# longboat: 9 times
# Jar: 2 times
# dirt: 13 times
# undefined: 12 times
# reference: 8 times
# `: 7 times
# nsSystemPrefModule_gModuleInfo: 1 times
# nsStaticComponents: 1 times
# o: 45 times
# ): 586 times
# Build: 16 times
# fails: 135 times
# gcc: 3 times
# 95: 15 times
# Autocomplete: 28 times
# present: 21 times
# options: 77 times
# blank: 61 times
# textfield: 4 times
# mouse: 100 times
# click: 214 times
# thing: 130 times
# Alberto: 1 times
# criticizes: 1 times
# everybody: 15 times
# drug: 12 times
# except: 26 times
# bone: 12 times
# Stranger: 9 times
# hear: 62 times
# bottle: 91 times
# wine: 196 times
# seems: 71 times
# past: 30 times
# varied: 2 times
# between: 72 times
# stars: 8 times
# HERBERT: 22 times
# Hurry: 9 times
# gay: 86 times
# Top: 161 times
# pale: 4 times
# colour: 35 times
# sediment: 1 times
# fasten: 1 times
# seatbelt: 1 times
# lit: 2 times
# China: 10 times
# working: 110 times
# rice: 9 times
# paddies: 1 times
# 40: 21 times
# preggers: 3 times
# So: 451 times
# insisted: 1 times
# coming: 47 times
# room: 48 times
# last: 161 times
# pelvic: 2 times
# exam: 4 times
# LORD: 26 times
# CUTLER: 26 times
# BECKETT: 26 times
# By: 13 times
# efforts: 3 times
# set: 107 times
# free: 39 times
# FTP: 14 times
# Firebird: 348 times
# enter: 51 times
# username: 17 times
# password: 89 times
# anonymous: 4 times
# login: 41 times
# supported: 9 times
# scroll: 102 times
# temprementally: 1 times
# full: 61 times
# Properties: 10 times
# Inaccessible: 1 times
# patch: 14 times
# bug: 45 times
# 224748: 1 times
# reflected: 2 times
# intl: 1 times
# properties: 32 times
# toolkit: 9 times
# photo: 5 times
# locked: 12 times
# XPcom: 1 times
# chainsaw: 3 times
# been: 179 times
# four: 39 times
# hours: 25 times
# hell: 35 times
# kind: 68 times
# name: 158 times
# anyway: 37 times
# Pause: 15 times
# yelling: 13 times
# other: 228 times
# line: 95 times
# NWA: 1 times
# album: 1 times
# CRONE: 7 times
# Aggh: 1 times
# single: 35 times
# down: 261 times
# sure: 82 times
# visit: 15 times
# are: 863 times
# doing: 76 times
# sucks: 19 times
# Suburbanite: 4 times
# relationship: 38 times
# eight: 9 times
# Professor: 42 times
# Okay: 57 times
# pronounce: 2 times
# wanton: 1 times
# .': 31 times
# Smoky: 4 times
# cigary: 1 times
# classic: 21 times
# world: 46 times
# doesn: 478 times
# Well: 333 times
# least: 61 times
# slept: 16 times
# week: 36 times
# hadn: 4 times
# would: 284 times
# Egypt: 3 times
# daughter: 24 times
# look: 184 times
# upon: 36 times
# her: 424 times
# dad: 45 times
# real: 78 times
# legally: 1 times
# binding: 10 times
# sense: 32 times
# favorite: 18 times
# sweatshirt: 3 times
# Firefox: 495 times
# crashed: 16 times
# creating: 13 times
# blog: 3 times
# entry: 37 times
# blogger: 1 times
# com: 109 times
# HEAD: 47 times
# 20040513: 1 times
# hang: 42 times
# Buttons: 9 times
# extension: 99 times
# work: 433 times
# Exception: 4 times
# XPCOM: 5 times
# EventReceiver: 3 times
# reordering: 2 times
# extensions: 76 times
# manager: 201 times
# correctly: 69 times
# Failed: 6 times
# theme: 123 times
# downloads: 45 times
# display: 132 times
# error: 163 times
# Hard: 10 times
# boom: 26 times
# Hm: 2 times
# Daughter: 4 times
# Hooters: 1 times
# little: 136 times
# center: 6 times
# true: 32 times
# read: 42 times
# internet: 18 times
# This: 218 times
# supposed: 34 times
# quality: 20 times
# Drunk: 172 times
# straight: 23 times
# printing: 16 times
# Right: 75 times
# SUB: 1 times
# folder: 157 times
# selecting: 34 times
# manage: 18 times
# leaves: 23 times
# open: 470 times
# top: 89 times
# bookmark: 256 times
# invisibly: 1 times
# deleting: 22 times
# letter: 16 times
# files: 130 times
# cut: 50 times
# Improvement: 1 times
# Installation: 9 times
# Java: 32 times
# Plugin: 13 times
# Crash: 106 times
# attempting: 20 times
# provide: 5 times
# proxy: 46 times
# server: 34 times
# delete: 36 times
# Bookmarks: 188 times
# Toolbar: 132 times
# Folder: 42 times
# Obsolete: 1 times
# root: 18 times
# certificate: 22 times
# Customization: 5 times
# allowed: 16 times
# refreshing: 11 times
# w: 18 times
# post: 10 times
# args: 2 times
# doesnt: 30 times
# resend: 1 times
# pages: 123 times
# fully: 14 times
# load: 109 times
# nightlies: 10 times
# 0: 303 times
# 7: 66 times
# loading: 97 times
# NYTimes: 2 times
# Washington: 8 times
# index: 2 times
# page: 598 times
# altss: 1 times
# Style: 4 times
# selector: 4 times
# Theme: 33 times
# without: 115 times
# base: 12 times
# stylesheet: 15 times
# shows: 80 times
# Basic: 3 times
# vertical: 9 times
# bars: 20 times
# main: 43 times
# Ever: 8 times
# Just: 76 times
# start: 141 times
# thirties: 2 times
# Yarmulke: 8 times
# Could: 24 times
# finally: 18 times
# clovers: 1 times
# wasted: 6 times
# night: 86 times
# Leaving: 2 times
# loudly: 8 times
# Jeany: 1 times
# Get: 65 times
# devil: 13 times
# pay: 27 times
# Excellent: 21 times
# marred: 2 times
# ever: 133 times
# slightly: 40 times
# raw: 9 times
# woody: 9 times
# background: 82 times
# Wall: 7 times
# Street: 45 times
# sorry: 53 times
# Rough: 1 times
# heard: 60 times
# Columbia: 13 times
# Snacks: 1 times
# actually: 42 times
# pot: 17 times
# service: 24 times
# Blonde: 22 times
# Gasp: 3 times
# bet: 18 times
# totally: 88 times
# nappy: 2 times
# hair: 56 times
# son: 57 times
# Nurse: 3 times
# Poland: 2 times
# Human: 2 times
# sacrifice: 2 times
# red: 31 times
# bouncing: 3 times
# balls: 21 times
# cool: 38 times
# sand: 12 times
# during: 32 times
# vacation: 3 times
# ****: 145 times
# Yummy: 1 times
# drinkability: 1 times
# need: 232 times
# .": 133 times
# more: 283 times
# glass: 39 times
# Rocker: 2 times
# doof: 2 times
# movie: 42 times
# grunge: 1 times
# whatever: 36 times
# everyone: 56 times
# wearing: 48 times
# flannel: 2 times
# wasn: 63 times
# ironic: 7 times
# Up: 10 times
# Fat: 9 times
# Albert: 1 times
# store: 32 times
# External: 3 times
# ICQ: 2 times
# client: 14 times
# Thunderbird: 28 times
# stay: 49 times
# Clicking: 53 times
# middle: 75 times
# button: 308 times
# google: 33 times
# search: 176 times
# failed: 21 times
# unused: 5 times
# variables: 3 times
# config: 20 times
# mldonkey: 1 times
# Combination: 1 times
# hover: 10 times
# <: 74 times
# textarea: 10 times
# >: 109 times
# Crashes: 20 times
# Deleting: 4 times
# Item: 3 times
# Arrow: 3 times
# Key: 4 times
# Press: 2 times
# Please: 53 times
# add: 77 times
# Print: 40 times
# function: 40 times
# context: 89 times
# Download: 126 times
# eternal: 1 times
# comparision: 1 times
# IE: 51 times
# 6: 76 times
# Sun: 8 times
# JVM: 1 times
# 2_03: 1 times
# Show: 31 times
# URLs: 32 times
# History: 50 times
# Scroll: 16 times
# bar: 392 times
# Dec: 1 times
# 14th: 5 times
# nightly: 20 times
# Suit: 111 times
# Excuse: 79 times
# phone: 52 times
# Peggy: 1 times
# lived: 8 times
# goddamn: 7 times
# city: 37 times
# 32: 8 times
# years: 99 times
# ELIZABETH: 77 times
# SWANN: 77 times
# faith: 7 times
# honey: 31 times
# But: 248 times
# remains: 15 times
# chief: 6 times
# acts: 4 times
# help: 91 times
# Store: 40 times
# lady: 266 times
# paper: 22 times
# bags: 17 times
# trees: 9 times
# Fascinating: 1 times
# given: 28 times
# lack: 7 times
# clarity: 3 times
# Capitalist: 1 times
# bastards: 2 times
# Amateur: 5 times
# anthropologist: 1 times
# incest: 2 times
# unless: 22 times
# Hobo: 200 times
# Thanks: 18 times
# Grandma: 19 times
# Who: 89 times
# category: 3 times
# questions: 16 times
# answered: 4 times
# under: 83 times
# jurisdiction: 1 times
# King: 33 times
# governor: 9 times
# Port: 11 times
# Royal: 5 times
# charged: 3 times
# Has: 10 times
# makings: 1 times
# La: 3 times
# Chapelle: 1 times
# Minimalist: 1 times
# paintings: 1 times
# flags: 1 times
# Mark: 7 times
# Rothko: 1 times
# Welcome: 12 times
# Japan: 6 times
# He: 286 times
# rescue: 4 times
# terrorist: 6 times
# party: 36 times
# wait: 46 times
# Does: 40 times
# family: 19 times
# ham: 3 times
# turkey: 4 times
# Christmas: 17 times
# dinner: 21 times
# Pizza: 3 times
# eggplant: 2 times
# Why: 180 times
# Cookie: 17 times
# handling: 22 times
# indicated: 2 times
# specific: 21 times
# won: 142 times
# allow: 39 times
# 46: 4 times
# BCC: 2 times
# addresses: 5 times
# MSN: 1 times
# Hotmail: 11 times
# FireFox: 38 times
# dosn: 2 times
# version: 59 times
# numbers: 14 times
# Programs: 3 times
# extenstion: 2 times
# opens: 108 times
# wrong: 142 times
# Border: 1 times
# panes: 2 times
# new: 414 times
# expand: 24 times
# widget: 5 times
# folders: 51 times
# subfolders: 4 times
# pane: 9 times
# Native: 6 times
# Doodling: 1 times
# Find: 75 times
# As: 55 times
# Type: 12 times
# Dialogs: 4 times
# jump: 14 times
# screen: 87 times
# title: 29 times
# give: 137 times
# change: 113 times
# sidebars: 6 times
# Add: 123 times
# customize: 34 times
# www: 56 times
# odeon: 4 times
# co: 18 times
# uk: 6 times
# Scrolling: 8 times
# Credits: 6 times
# nessisary: 1 times
# facial: 1 times
# pull: 26 times
# Fu: 1 times
# Chu: 1 times
# cop: 12 times
# porn: 15 times
# star: 14 times
# pirate: 10 times
# Wonan: 1 times
# getting: 85 times
# married: 45 times
# Holy: 28 times
# Latina: 11 times
# six: 21 times
# hour: 17 times
# minimum: 7 times
# "?: 36 times
# Bare: 98 times
# Perfectly: 4 times
# nondescript: 3 times
# part: 54 times
# Brooklyn: 43 times
# an: 434 times
# adult: 2 times
# hipster: 28 times
# water: 35 times
# terrible: 12 times
# Ooh: 16 times
# Did: 77 times
# threesome: 7 times
# Trista: 1 times
# Hipster: 154 times
# dude: 72 times
# Uh: 69 times
# gave: 34 times
# Fuck: 63 times
# wanted: 58 times
# doctor: 27 times
# Kenneth: 1 times
# Cole: 1 times
# Tarry: 2 times
# hard: 58 times
# After: 57 times
# train: 215 times
# put: 96 times
# stranded: 3 times
# exactly: 15 times
# DtoE: 4 times
# SOH: 4 times
# seeks: 39 times
# 38: 4 times
# 50: 41 times
# children: 37 times
# ok: 24 times
# Fship: 2 times
# poss: 9 times
# Rship: 1 times
# genuine: 10 times
# replies: 1 times
# Naked: 3 times
# suit: 30 times
# building: 31 times
# Price: 2 times
# Waterhouse: 1 times
# Ernst: 1 times
# &: 145 times
# burn: 12 times
# Click: 24 times
# submit: 26 times
# headline: 2 times
# pause: 32 times
# sad: 6 times
# Tuh: 2 times
# tuh: 4 times
# Toddler: 11 times
# fuck: 149 times
# whose: 11 times
# coochie: 4 times
# stomach: 8 times
# ZOOT: 14 times
# doctors: 3 times
# immediately: 21 times
# Really: 61 times
# ugly: 34 times
# Ha: 62 times
# High: 27 times
# toned: 44 times
# cranberry: 4 times
# underlying: 10 times
# meatiness: 1 times
# excellent: 13 times
# Boy: 46 times
# Stuck: 3 times
# Tween: 59 times
# arguing: 3 times
# whether: 16 times
# haha: 1 times
# l: 5 times
# funnier: 1 times
# Mom: 161 times
# Stop: 58 times
# scratching: 1 times
# yourself: 30 times
# Biker: 9 times
# unicorns: 1 times
# pots: 2 times
# gold: 9 times
# wants: 38 times
# anyone: 47 times
# Hopelessly: 1 times
# oxidised: 10 times
# surely: 5 times
# odd: 20 times
# Shit: 30 times
# tomorrow: 17 times
# Ctrl: 85 times
# +: 206 times
# Enter: 24 times
# v0: 3 times
# opening: 138 times
# html: 49 times
# document: 44 times
# Ferinte: 1 times
# WLTM: 10 times
# attractive: 45 times
# classy: 12 times
# med: 6 times
# outings: 3 times
# weekends: 5 times
# away: 118 times
# perm: 3 times
# rship: 12 times
# suited: 1 times
# Mercea: 2 times
# elected: 1 times
# chance: 14 times
# though: 65 times
# glorious: 3 times
# claret: 4 times
# warm: 23 times
# pencil: 4 times
# shaving: 2 times
# nose: 134 times
# Business: 5 times
# rather: 97 times
# husband: 24 times
# buy: 64 times
# products: 5 times
# Star: 5 times
# Wars: 4 times
# Eccentric: 1 times
# rancio: 2 times
# complex: 48 times
# interesting: 25 times
# All: 112 times
# dough: 3 times
# wear: 35 times
# clothes: 19 times
# drinkable: 32 times
# F: 24 times
# take: 207 times
# nothin: 10 times
# '.: 40 times
# she: 482 times
# roll: 14 times
# weed: 27 times
# Him: 2 times
# stopped: 18 times
# loving: 8 times
# Isn: 29 times
# also: 36 times
# excuse: 7 times
# drinking: 92 times
# ye: 2 times
# serve: 5 times
# My: 168 times
# cousin: 8 times
# owns: 4 times
# station: 16 times
# Thug: 33 times
# gotta: 58 times
# pee: 32 times
# potty: 1 times
# corked: 5 times
# divorced: 2 times
# kids: 70 times
# live: 46 times
# home: 123 times
# parents: 23 times
# Boss: 1 times
# story: 19 times
# passionately: 1 times
# kisses: 2 times
# sees: 17 times
# kiss: 16 times
# falters: 1 times
# GIBBS: 70 times
# Prepare: 2 times
# cast: 6 times
# deep: 16 times
# bright: 14 times
# Patient: 5 times
# Penicillin: 1 times
# sank: 3 times
# swamp: 7 times
# GENUINE: 2 times
# AND: 10 times
# HONEST: 1 times
# Hi: 16 times
# Im: 4 times
# 44: 2 times
# humour: 5 times
# romantic: 2 times
# drives: 10 times
# fishing: 10 times
# camping: 4 times
# music: 52 times
# Ooo: 2 times
# hospitable: 2 times
# holding: 37 times
# infant: 4 times
# feminine: 4 times
# maxi: 1 times
# pads: 2 times
# baby: 93 times
# chihuahua: 2 times
# Yes: 116 times
# commodification: 1 times
# desires: 1 times
# annoying: 6 times
# isn: 83 times
# MouseImp: 1 times
# option: 114 times
# javascript: 71 times
# console: 17 times
# blinks: 2 times
# non: 84 times
# added: 25 times
# focus: 92 times
# ESC: 2 times
# close: 144 times
# viewSource: 1 times
# Window: 36 times
# FAYT: 2 times
# missing: 95 times
# block: 18 times
# cokies: 1 times
# popups: 23 times
# Screen: 18 times
# updates: 12 times
# tab: 377 times
# closed: 59 times
# Simple: 8 times
# hangs: 70 times
# Usability: 2 times
# Enhancement: 3 times
# Tab: 55 times
# Closing: 10 times
# icon: 133 times
# Pressing: 8 times
# trailing: 2 times
# favicons: 13 times
# protected: 7 times
# show: 134 times
# dialog: 263 times
# View: 64 times
# Source: 32 times
# update: 52 times
# through: 109 times
# POSTDATA: 4 times
# confirmation: 10 times
# ignores: 15 times
# selected: 63 times
# percentage: 9 times
# reduction: 2 times
# Damn: 31 times
# Bye: 5 times
# reunited: 1 times
# Child: 7 times
# dialogues: 1 times
# save: 97 times
# install: 100 times
# displayed: 71 times
# Windows: 94 times
# NT: 3 times
# Since: 10 times
# subways: 6 times
# high: 85 times
# alert: 27 times
# started: 37 times
# stuck: 26 times
# groopie: 3 times
# ho: 14 times
# standards: 7 times
# insult: 2 times
# computer: 19 times
# Don: 120 times
# Vanna: 3 times
# Looking: 14 times
# medium: 18 times
# 55: 6 times
# yrs: 5 times
# Pleasant: 19 times
# TIA: 21 times
# DALMA: 21 times
# Activist: 1 times
# kinda: 20 times
# political: 3 times
# goin: 15 times
# Wow: 46 times
# war: 6 times
# criminal: 4 times
# before: 107 times
# Remove: 31 times
# +-: 1 times
# ++: 6 times
# items: 52 times
# preview: 49 times
# problems: 38 times
# ;: 217 times
# ctrl: 44 times
# middleclick: 2 times
# loads: 36 times
# selection: 36 times
# current: 49 times
# appears: 68 times
# inactive: 9 times
# python: 2 times
# org: 30 times
# To: 41 times
# prevent: 8 times
# websites: 16 times
# detect: 4 times
# blocking: 28 times
# Positive: 1 times
# Feedback: 5 times
# gives: 40 times
# message: 67 times
# Internal: 2 times
# Too: 16 times
# recursion: 1 times
# brings: 16 times
# Clay: 1 times
# brought: 15 times
# fresh: 37 times
# Hot: 16 times
# dog: 98 times
# placed: 7 times
# order: 43 times
# ma: 19 times
# Times: 18 times
# seven: 7 times
# Snuffleupagus: 2 times
# respect: 23 times
# ring: 10 times
# tone: 4 times
# Apples: 6 times
# again: 125 times
# suggestion: 4 times
# Everyone: 16 times
# New: 242 times
# York: 115 times
# poops: 3 times
# river: 7 times
# .--: 9 times
# Ferry: 1 times
# Ellis: 2 times
# Island: 51 times
# Dental: 2 times
# hygienist: 2 times
# cultural: 3 times
# barriers: 2 times
# health: 3 times
# care: 56 times
# German: 11 times
# American: 27 times
# dental: 2 times
# hygienists: 1 times
# $: 42 times
# 500: 3 times
# deductables: 1 times
# instead: 117 times
# buried: 4 times
# y: 35 times
# digs: 2 times
# cannot: 124 times
# possibly: 15 times
# understand: 49 times
# cause: 87 times
# which: 95 times
# estrogen: 1 times
# chocolate: 22 times
# Still: 43 times
# dense: 8 times
# brown: 20 times
# sugar: 16 times
# follows: 5 times
# hint: 13 times
# volatility: 8 times
# looks: 91 times
# 26: 6 times
# pissed: 11 times
# liked: 10 times
# cinematography: 1 times
# julia: 1 times
# face: 76 times
# slash: 5 times
# mouth: 40 times
# pole: 17 times
# Prefs: 6 times
# Bugzilla: 8 times
# crashes: 227 times
# Tabbrowser: 4 times
# Extension: 46 times
# settings: 36 times
# unavailable: 6 times
# left: 127 times
# place: 81 times
# refresh: 25 times
# flashes: 5 times
# 30: 36 times
# continually: 2 times
# rendered: 20 times
# Extra: 2 times
# white: 137 times
# DIVs: 1 times
# Wobbly: 1 times
# legged: 4 times
# rum: 11 times
# soaked: 1 times
# pirates: 2 times
# *!: 10 times
# Making: 3 times
# ready: 22 times
# tosail: 1 times
# ###,: 2 times
# Elegantly: 1 times
# salad: 6 times
# costume: 2 times
# shop: 2 times
# somewhere: 11 times
# Looks: 5 times
# bag: 41 times
# hip: 7 times
# Teacher: 11 times
# Ok: 22 times
# settle: 7 times
# watch: 48 times
# biography: 2 times
# video: 13 times
# anymore: 44 times
# break: 30 times
# breaking: 9 times
# side: 56 times
# Bridge: 7 times
# Staten: 5 times
# guess: 75 times
# lot: 96 times
# common: 9 times
# Soft: 13 times
# slight: 12 times
# spritz: 4 times
# Pretty: 24 times
# Shhhh: 1 times
# Southern: 19 times
# pocketbook: 1 times
# tonight: 50 times
# cook: 8 times
# crab: 11 times
# suck: 23 times
# Of: 21 times
# course: 33 times
# everything: 40 times
# Upper: 11 times
# East: 24 times
# Side: 12 times
# their: 120 times
# lesser: 2 times
# wines: 41 times
# credit: 14 times
# property: 18 times
# Cop: 23 times
# grabbed: 4 times
# God: 106 times
# racist: 9 times
# Or: 30 times
# maybe: 50 times
# boob: 2 times
# job: 41 times
# rusty: 1 times
# butter: 14 times
# knife: 11 times
# balloons: 3 times
# MAYNARD: 8 times
# J: 6 times
# practically: 2 times
# Jewish: 41 times
# bathroom: 26 times
# Anna: 1 times
# cookie: 33 times
# Suck: 3 times
# fallopian: 1 times
# tubes: 1 times
# Big: 16 times
# ***(*): 70 times
# More: 28 times
# floral: 11 times
# Caillerets: 2 times
# Grandpa: 4 times
# shoes: 20 times
# belt: 4 times
# Crazy: 80 times
# aren: 39 times
# listening: 12 times
# talk: 64 times
# Bill: 7 times
# Batson: 1 times
# Americans: 5 times
# over: 253 times
# hammered: 2 times
# struck: 1 times
# subway: 35 times
# shouldn: 31 times
# sunglasses: 2 times
# enough: 74 times
# air: 19 times
# since: 42 times
# breathe: 6 times
# eyes: 34 times
# Shh: 13 times
# instant: 1 times
# credibility: 1 times
# Gay: 21 times
# waiter: 4 times
# sterilize: 1 times
# might: 66 times
# fire: 36 times
# infection: 2 times
# vegetarian: 11 times
# Tell: 12 times
# tires: 1 times
# overturn: 1 times
# Seems: 12 times
# oxidatively: 1 times
# heavy: 12 times
# thud: 4 times
# hits: 9 times
# shout: 2 times
# MARTY: 6 times
# digital: 1 times
# sec: 8 times
# His: 9 times
# smashed: 1 times
# liver: 4 times
# removed: 22 times
# bowels: 1 times
# unplugged: 1 times
# nostrils: 1 times
# raped: 9 times
# bottom: 27 times
# burned: 4 times
# pen: 3 times
# SIR: 3 times
# ROBIN: 30 times
# uh: 49 times
# lads: 1 times
# Suspiciously: 1 times
# Open: 87 times
# Keyboard: 14 times
# Shortcuts: 6 times
# Working: 6 times
# UI: 57 times
# implementation: 3 times
# changing: 33 times
# image: 119 times
# animation_mode: 1 times
# leak: 5 times
# starting: 38 times
# exiting: 6 times
# instances: 10 times
# freeze: 17 times
# permanently: 3 times
# slow: 48 times
# loaded: 37 times
# connection: 31 times
# Font: 18 times
# used: 108 times
# Page: 133 times
# info: 27 times
# consistent: 5 times
# wheel: 52 times
# displaying: 22 times
# printable: 1 times
# characters: 42 times
# directory: 55 times
# using: 198 times
# filer: 1 times
# Fantastically: 1 times
# appearance: 4 times
# Chocolate: 7 times
# Chip: 1 times
# Muffin: 1 times
# revisionist: 1 times
# Ladies: 19 times
# gentlemen: 20 times
# rush: 9 times
# onto: 30 times
# pushing: 9 times
# others: 13 times
# risking: 1 times
# fall: 14 times
# injury: 3 times
# worse: 16 times
# Newark: 3 times
# GALAHAD: 58 times
# later: 36 times
# medicine: 5 times
# cabinet: 1 times
# textured: 15 times
# vintage: 45 times
# call: 102 times
# Some: 40 times
# Chanel: 1 times
# usually: 11 times
# 45: 16 times
# reached: 6 times
# approaches: 3 times
# City: 23 times
# Hall: 6 times
# happened: 32 times
# thought: 89 times
# pill: 4 times
# talkin: 8 times
# bout: 7 times
# Epoxy: 1 times
# dat: 15 times
# wench: 1 times
# ",: 11 times
# Wherefore: 1 times
# thou: 6 times
# careers: 1 times
# malfunction: 1 times
# Main: 5 times
# Default: 40 times
# Context: 23 times
# offer: 13 times
# GO: 2 times
# TO: 6 times
# urls: 8 times
# hyperlinks: 2 times
# Safari: 3 times
# Legends: 1 times
# dialogs: 20 times
# shown: 47 times
# mode: 40 times
# minimize: 9 times
# maximize: 4 times
# buttons: 101 times
# Ability: 21 times
# move: 58 times
# view: 86 times
# Cannot: 69 times
# external: 30 times
# links: 107 times
# replacing: 3 times
# process: 17 times
# run: 60 times
# application: 64 times
# GUI: 7 times
# launch: 41 times
# NewsMonster: 1 times
# downlad: 1 times
# dir: 10 times
# fills: 6 times
# Plugins: 5 times
# easy: 45 times
# share: 15 times
# groups: 10 times
# Customize: 30 times
# Dialog: 28 times
# Done: 7 times
# import: 31 times
# export: 9 times
# bookmarks: 290 times
# box: 134 times
# breaks: 40 times
# auto: 31 times
# fieldset: 4 times
# tag: 34 times
# frames: 16 times
# corners: 1 times
# disconnected: 3 times
# Links: 13 times
# E: 19 times
# 51: 2 times
# Citrix: 1 times
# WinFrame: 1 times
# Gtk: 1 times
# WARNING: 1 times
# **:: 2 times
# invalid: 13 times
# NULL: 2 times
# pointer: 13 times
# GtkObject: 1 times
# showing: 46 times
# win98: 2 times
# location: 108 times
# dropdown: 47 times
# accidentaly: 1 times
# scrolling: 59 times
# Parts: 1 times
# Preview: 22 times
# steal: 14 times
# file: 266 times
# associations: 7 times
# ftp: 8 times
# listings: 1 times
# 2003: 15 times
# modified: 7 times
# 2004: 8 times
# throbber: 15 times
# Browser: 66 times
# closes: 26 times
# World: 15 times
# Fair: 4 times
# Middle: 54 times
# aged: 21 times
# yeah: 103 times
# takes: 39 times
# pound: 18 times
# reindeer: 1 times
# ground: 18 times
# front: 49 times
# places: 9 times
# differently: 7 times
# named: 24 times
# depending: 4 times
# cursor: 40 times
# visible: 30 times
# Museum: 6 times
# Sex: 9 times
# CROWD: 17 times
# pond: 2 times
# url: 117 times
# Javascript: 53 times
# support: 56 times
# form: 110 times
# [': 1 times
# radioButtonGroup: 1 times
# '].: 1 times
# x: 17 times
# select: 49 times
# helper: 9 times
# applications: 12 times
# With: 23 times
# preferences: 85 times
# stops: 61 times
# responding: 19 times
# Image: 37 times
# =: 36 times
# Shift: 22 times
# input: 56 times
# autoscroll: 18 times
# interferes: 2 times
# pasting: 4 times
# fields: 28 times
# column: 17 times
# third: 25 times
# 2nd: 7 times
# source: 49 times
# needs: 87 times
# print: 86 times
# Form: 31 times
# nothing: 60 times
# custom: 11 times
# sized: 7 times
# Locale: 1 times
# Switching: 10 times
# Chemdraw: 1 times
# net: 22 times
# plugin: 45 times
# properly: 70 times
# crewmember: 9 times
# body: 32 times
# height: 11 times
# splashing: 1 times
# investigate: 3 times
# tried: 31 times
# waxing: 1 times
# font: 22 times
# apply: 10 times
# menus: 62 times
# etc: 13 times
# TIM: 25 times
# Look: 82 times
# sayin: 11 times
# '?: 19 times
# thunderstorm: 2 times
# Scene: 29 times
# PORT: 4 times
# ROYAL: 4 times
# EITC: 5 times
# HEADQUARTERS: 1 times
# painter: 1 times
# painting: 9 times
# detail: 2 times
# mural: 1 times
# map: 13 times
# guard: 16 times
# manacles: 3 times
# Beckett: 15 times
# office: 12 times
# Lord: 19 times
# Again: 7 times
# beautifully: 3 times
# Metabolize: 1 times
# Against: 3 times
# beats: 1 times
# Mineral: 13 times
# fairly: 22 times
# austere: 5 times
# flavoury: 2 times
# Bronx: 10 times
# borough: 2 times
# word: 46 times
# learn: 17 times
# speaking: 7 times
# English: 39 times
# Latino: 3 times
# younger: 12 times
# Listen: 16 times
# rights: 9 times
# c: 16 times
# mon: 10 times
# screaming: 20 times
# threaten: 1 times
# jail: 17 times
# Metal: 2 times
# craving: 2 times
# burgundy: 1 times
# Give: 22 times
# piss: 13 times
# STDs: 6 times
# waiting: 25 times
# ?!: 47 times
# our: 69 times
# stores: 6 times
# St: 21 times
# Louis: 4 times
# area: 42 times
# titties: 8 times
# mmm: 4 times
# Nice: 52 times
# Date: 3 times
# Huh: 19 times
# Exactly: 5 times
# Fo: 3 times
# sho: 2 times
# default: 176 times
# primary: 11 times
# dual: 14 times
# monitor: 24 times
# invoked: 3 times
# impossible: 10 times
# faded: 4 times
# lightweight: 5 times
# find: 155 times
# entering: 18 times
# tools: 16 times
# ->: 102 times
# segmentation: 3 times
# fault: 18 times
# Hint: 1 times
# less: 46 times
# scrolled: 5 times
# subdialog: 1 times
# giving: 28 times
# space: 30 times
# WITCH: 4 times
# fair: 12 times
# almost: 41 times
# CD: 4 times
# vendor: 16 times
# hop: 5 times
# charges: 3 times
# Balloon: 1 times
# twisting: 1 times
# clown: 2 times
# Animals: 1 times
# minerals: 4 times
# vegetables: 3 times
# BO: 6 times
# SUN: 8 times
# Step: 3 times
# tight: 18 times
# Fabian: 1 times
# human: 20 times
# horse: 18 times
# known: 10 times
# mumble: 6 times
# Ay: 2 times
# bomb: 3 times
# Teenage: 20 times
# South: 19 times
# pruney: 3 times
# unsatifyingly: 1 times
# remote: 24 times
# smoking: 20 times
# wake: 11 times
# asked: 33 times
# unchristian: 1 times
# Deli: 10 times
# shoot: 16 times
# *.: 22 times
# taken: 13 times
# flock: 1 times
# bees: 2 times
# moldy: 1 times
# bread: 11 times
# handle: 18 times
# easily: 11 times
# Come: 81 times
# violence: 2 times
# inherent: 2 times
# system: 53 times
# jar: 29 times
# eyeballs: 1 times
# hanging: 16 times
# Ragetti: 25 times
# speaks: 1 times
# Davy: 11 times
# Jones: 43 times
# yes: 34 times
# drive: 14 times
# milk: 8 times
# trucks: 2 times
# snack: 1 times
# fact: 19 times
# unwind: 1 times
# bum: 5 times
# Jasmin: 1 times
# Funky: 1 times
# age: 46 times
# substantial: 9 times
# happening: 9 times
# castration: 1 times
# masturbation: 2 times
# amputation: 1 times
# AIDS: 15 times
# purpose: 10 times
# ston: 3 times
# explains: 1 times
# French: 31 times
# skateboard: 1 times
# local: 31 times
# D: 35 times
# hearts: 2 times
# squeak: 28 times
# rrrr: 3 times
# drilllll: 1 times
# sawwwww: 1 times
# clunk: 4 times
# clang: 13 times
# ...]: 4 times
# creak: 2 times
# GUARDS: 7 times
# whispering: 7 times
# C: 23 times
# est: 2 times
# un: 4 times
# lapin: 2 times
# bois: 4 times
# Run: 30 times
# Bobby: 2 times
# Demanding: 1 times
# succulent: 9 times
# Wanna: 9 times
# Jesus: 58 times
# trophy: 4 times
# Ticket: 3 times
# gal: 2 times
# bacteria: 1 times
# above: 34 times
# Need: 42 times
# contrast: 4 times
# distinguish: 2 times
# active: 27 times
# Cookies: 15 times
# Preference: 5 times
# originating: 6 times
# settable: 2 times
# Go: 55 times
# updated: 22 times
# browsing: 33 times
# Preferences: 53 times
# First: 18 times
# Save: 65 times
# presented: 7 times
# unable: 25 times
# code: 37 times
# idl: 1 times
# domains: 5 times
# redirect: 8 times
# leaving: 17 times
# ":": 1 times
# notification: 12 times
# bring: 30 times
# Selection: 8 times
# proper: 13 times
# controls: 4 times
# Hotkeys: 1 times
# user: 77 times
# js: 39 times
# immediatly: 1 times
# mentioning: 2 times
# problem: 81 times
# backqoutes: 1 times
# enabling: 1 times
# disabling: 7 times
# Load: 12 times
# images: 81 times
# Start: 22 times
# downloading: 46 times
# paused: 1 times
# deletes: 8 times
# position: 25 times
# Login: 7 times
# Online: 4 times
# Enterprise: 1 times
# Architect: 1 times
# Magazine: 1 times
# Easy: 16 times
# EMBEDded: 1 times
# media: 10 times
# via: 34 times
# null: 5 times
# Chromeless: 1 times
# ENTER: 5 times
# CHROMELESS: 1 times
# VERSION: 1 times
# "): 17 times
# Unnecessary: 4 times
# Security: 40 times
# Warning: 6 times
# Submittal: 1 times
# HTTPS: 4 times
# Title: 7 times
# cursive: 1 times
# sra: 1 times
# Salaa: 1 times
# TRANSPARENT: 1 times
# FLASH: 3 times
# parts: 6 times
# Scrollbar: 11 times
# coloured: 8 times
# percent: 9 times
# value: 27 times
# recognize: 13 times
# HEADER: 1 times
# tags: 17 times
# h4: 1 times
# accurately: 3 times
# TABLES: 1 times
# drawn: 7 times
# incorrectly: 35 times
# Change: 21 times
# customization: 11 times
# text: 228 times
# include: 15 times
# removal: 2 times
# Allow: 17 times
# keyword: 19 times
# searches: 8 times
# HTML: 29 times
# <!--: 1 times
# Comment: 2 times
# -->: 11 times
# passing: 11 times
# beyond: 12 times
# club: 13 times
# bacon: 6 times
# egg: 7 times
# cheese: 20 times
# choice: 13 times
# Fx: 3 times
# pressing: 18 times
# XML: 36 times
# tree: 33 times
# causes: 126 times
# vanish: 1 times
# DOM: 16 times
# Inspector: 15 times
# persistent: 7 times
# early: 20 times
# OK: 64 times
# Options: 112 times
# manually: 11 times
# typing: 20 times
# homepage: 29 times
# scrollbars: 14 times
# havbe: 1 times
# foreward: 1 times
# navigation: 24 times
# specified: 15 times
# status: 39 times
# XP: 29 times
# Themes: 23 times
# themes: 58 times
# https: 20 times
# sites: 60 times
# Release: 6 times
# i586: 1 times
# compatible: 7 times
# builds: 35 times
# Linux: 38 times
# clean: 28 times
# second: 64 times
# chosen: 9 times
# tick: 3 times
# **(*): 43 times
# Concentrated: 1 times
# rich: 70 times
# tannic: 23 times
# Slutty: 2 times
# girlfriend: 44 times
# thick: 4 times
# Book: 3 times
# Proverbs: 1 times
# homeless: 28 times
# pooty: 1 times
# gorgeous: 8 times
# wife: 44 times
# smokes: 3 times
# affects: 3 times
# amazing: 9 times
# Hmm: 12 times
# Consider: 2 times
# calculations: 2 times
# imagine: 16 times
# orange: 19 times
# juice: 16 times
# sushi: 9 times
# Alzheimer: 5 times
# ";: 2 times
# Oldsheimer: 1 times
# taking: 43 times
# rolling: 7 times
# L: 17 times
# Yorkers: 13 times
# Umm: 4 times
# boyfriend: 42 times
# mister: 6 times
# Thank: 23 times
# Once: 16 times
# pantsless: 1 times
# Thanksgiving: 3 times
# Noodles: 1 times
# Harvard: 3 times
# Canada: 6 times
# Take: 11 times
# surprise: 8 times
# girlfriends: 2 times
# England: 9 times
# ??: 7 times
# watching: 15 times
# godfather: 2 times
# perhaps: 58 times
# money: 110 times
# Initially: 2 times
# modern: 19 times
# flashy: 1 times
# rock: 22 times
# owner: 14 times
# pizza: 14 times
# Hasta: 1 times
# ntilde: 1 times
# ana: 1 times
# CARRUTHERS: 2 times
# Mister: 10 times
# Swann: 2 times
# Compass: 18 times
# Christians: 1 times
# once: 54 times
# thousand: 11 times
# Spotted: 1 times
# Pig: 1 times
# cow: 10 times
# Then: 56 times
# LEECH: 4 times
# Actually: 18 times
# homosexuals: 3 times
# revolution: 1 times
# fades: 2 times
# customise: 1 times
# included: 7 times
# div: 12 times
# areas: 5 times
# outside: 41 times
# automatically: 26 times
# Hide: 10 times
# unchecked: 9 times
# Phoenix: 152 times
# broken: 105 times
# os: 11 times
# navbar: 1 times
# shutdown: 6 times
# brand: 6 times
# stick: 19 times
# cooter: 2 times
# Scrapes: 11 times
# forward: 52 times
# vanilla: 7 times
# enjoyable: 12 times
# seem: 36 times
# guts: 1 times
# keeper: 1 times
# shrubberies: 4 times
# Whole: 3 times
# Foods: 1 times
# yuppied: 1 times
# itself: 23 times
# sever: 2 times
# hold: 18 times
# cargo: 2 times
# pants: 40 times
# hurry: 13 times
# tunnel: 4 times
# containers: 1 times
# lunging: 1 times
# random: 19 times
# customer: 24 times
# where: 158 times
# Oy: 4 times
# beautiful: 30 times
# Bring: 17 times
# dead: 79 times
# tangy: 2 times
# hints: 9 times
# sometimes: 51 times
# mayhem: 2 times
# Delicious: 10 times
# Flight: 10 times
# attendant: 16 times
# overheard: 1 times
# disassemble: 1 times
# firearm: 3 times
# anything: 93 times
# intense: 35 times
# Six: 6 times
# Cent: 1 times
# Be: 11 times
# careful: 3 times
# bagel: 6 times
# ones: 24 times
# Japanese: 20 times
# tourist: 64 times
# thank: 12 times
# looked: 22 times
# peaceful: 3 times
# kick: 11 times
# awesome: 18 times
# selling: 18 times
# belts: 4 times
# Getcha: 2 times
# hitcha: 1 times
# moose: 5 times
# eat: 87 times
# jam: 5 times
# spam: 1 times
# dancing: 7 times
# Round: 8 times
# Table: 16 times
# Buy: 4 times
# fiction: 6 times
# win: 7 times
# lotto: 2 times
# jackpot: 2 times
# OFFICER: 10 times
# conversation: 18 times
# Macdougal: 3 times
# Ale: 1 times
# House: 1 times
# bathrooms: 2 times
# roommate: 2 times
# sleeps: 4 times
# bunk: 1 times
# alive: 11 times
# tired: 12 times
# playing: 19 times
# Twister: 1 times
# pajamas: 2 times
# witch: 28 times
# meteors: 2 times
# Female: 36 times
# cheap: 16 times
# Trojans: 2 times
# Opens: 10 times
# great: 77 times
# concentration: 20 times
# drink: 84 times
# Amazingly: 1 times
# episode: 1 times
# Love: 8 times
# Lucy: 3 times
# talking: 70 times
# book: 33 times
# words: 20 times
# makes: 85 times
# There: 129 times
# survivors: 4 times
# Medium: 10 times
# term: 15 times
# unintentionally: 1 times
# Spain: 5 times
# Europe: 11 times
# Fragrant: 14 times
# rose: 4 times
# garden: 3 times
# cedar: 1 times
# tobacco: 9 times
# notes: 22 times
# Charles: 5 times
# Bronson: 3 times
# ruin: 2 times
# reminds: 8 times
# producers: 4 times
# similar: 21 times
# direction: 12 times
# Massa: 1 times
# Vecchia: 1 times
# Gravner: 3 times
# hundred: 26 times
# dollars: 32 times
# large: 52 times
# package: 11 times
# seat: 20 times
# worry: 25 times
# Aaron: 1 times
# Spelling: 2 times
# Mayor: 2 times
# Bloomberg: 2 times
# send: 32 times
# camp: 4 times
# Jersey: 22 times
# INSPECTOR: 5 times
# Intense: 8 times
# pure: 25 times
# cassis: 10 times
# Sure: 20 times
# ..: 20 times
# MySpace: 12 times
# truth: 8 times
# Diedre: 1 times
# Beautiful: 2 times
# none: 13 times
# correct: 16 times
# TRANSIENT_FOR: 1 times
# website: 47 times
# distribute: 1 times
# communicator: 3 times
# navigator: 8 times
# mailnews: 2 times
# cruft: 2 times
# swf: 4 times
# RFE: 22 times
# visited: 13 times
# Error: 64 times
# launching: 18 times
# XBL: 9 times
# references: 7 times
# chrome: 41 times
# :/: 9 times
# layout: 7 times
# debug: 5 times
# introduces: 1 times
# dependency: 2 times
# comm: 3 times
# filesize: 3 times
# bigger: 13 times
# 2147483647: 1 times
# KB: 1 times
# ^: 1 times
# 31: 4 times
# Keywords: 11 times
# localhost: 11 times
# Mime: 1 times
# changed: 22 times
# force: 8 times
# permission: 3 times
# Missing: 11 times
# localization: 4 times
# jars: 2 times
# Fonts: 8 times
# startup: 80 times
# SIGILL: 1 times
# libxpcom: 1 times
# unsigned: 1 times
# RH8: 1 times
# log: 13 times
# usaa: 1 times
# Body: 3 times
# Cyberarmy: 1 times
# surprising: 2 times
# Manage: 13 times
# Certificates: 5 times
# Devices: 2 times
# panels: 9 times
# narrow: 4 times
# mostly: 4 times
# profile: 83 times
# usability: 2 times
# request: 29 times
# setting: 32 times
# currently: 9 times
# Zip: 3 times
# recognise: 3 times
# xpi: 5 times
# managing: 3 times
# pain: 4 times
# action: 24 times
# address: 109 times
# press: 15 times
# Menu: 53 times
# Empty: 9 times
# highlighting: 9 times
# done: 56 times
# misalign: 1 times
# viewing: 25 times
# Frozen: 1 times
# Button: 14 times
# Plug: 8 times
# Matcheroo: 1 times
# Processed: 1 times
# contextmenu: 3 times
# linked: 2 times
# following: 17 times
# Combine: 1 times
# Reload: 8 times
# sourceid: 1 times
# parameter: 8 times
# quick: 17 times
# objects: 7 times
# command: 36 times
# Menus: 13 times
# disabled: 47 times
# Toolbars: 21 times
# until: 72 times
# restarted: 2 times
# somtimes: 1 times
# alternative: 3 times
# appearing: 8 times
# expected: 17 times
# navigating: 5 times
# Popup: 30 times
# yahoo: 17 times
# finance: 3 times
# Progressive: 2 times
# rendering: 29 times
# repaint: 3 times
# grows: 4 times
# Proxy: 8 times
# bindings: 1 times
# incorrect: 33 times
# slows: 4 times
# near: 18 times
# useing: 1 times
# networks: 2 times
# port: 24 times
# magic: 4 times
# installed: 42 times
# GUESTS: 14 times
# wonderful: 5 times
# escape: 9 times
# Would: 36 times
# Blow: 2 times
# jobs: 5 times
# Dog: 1 times
# Fifi: 1 times
# ours: 3 times
# switch: 28 times
# Food: 1 times
# candy: 15 times
# Now: 58 times
# Harlem: 9 times
# safe: 5 times
# duty: 1 times
# knight: 3 times
# sample: 2 times
# peril: 6 times
# Simon: 3 times
# Cowell: 1 times
# forth: 6 times
# across: 25 times
# street: 39 times
# Yo: 114 times
# vagina: 29 times
# Straight: 10 times
# autocompletion: 6 times
# thunderbird: 4 times
# linux: 26 times
# Double: 19 times
# emptry: 1 times
# create: 31 times
# regression: 5 times
# 10th: 7 times
# July: 4 times
# control: 23 times
# invoke: 3 times
# Search: 52 times
# picks: 11 times
# available: 33 times
# autocomplete: 87 times
# multi: 8 times
# usage: 23 times
# completion: 7 times
# Arrowing: 1 times
# often: 22 times
# making: 36 times
# disappear: 31 times
# Using: 19 times
# results: 31 times
# inaccessible: 4 times
# unblock: 2 times
# apears: 1 times
# ftoolbar: 1 times
# disable: 40 times
# Saved: 12 times
# Information: 9 times
# Parents: 2 times
# shy: 4 times
# 17: 10 times
# shadow: 4 times
# smallest: 6 times
# fucked: 37 times
# plenty: 5 times
# jealous: 3 times
# Broker: 6 times
# pet: 3 times
# friendly: 6 times
# young: 46 times
# clerk: 12 times
# Whatsa: 1 times
# matter: 20 times
# ladies: 16 times
# hidden: 18 times
# pref: 35 times
# banner: 3 times
# ads: 3 times
# Migrator: 11 times
# migrate: 3 times
# data: 31 times
# Vertical: 5 times
# introduction: 1 times
# contents: 17 times
# shift: 14 times
# width: 13 times
# Cursor: 7 times
# positioned: 2 times
# cliams: 1 times
# accept: 26 times
# cookies: 55 times
# tho: 1 times
# enabled: 36 times
# certain: 48 times
# Urls: 1 times
# limited: 1 times
# duplicate: 9 times
# keywords: 14 times
# Sidebar: 31 times
# Sorry: 34 times
# Illinois: 3 times
# Chicago: 8 times
# Sputnik: 2 times
# continues: 6 times
# aerial: 4 times
# approaching: 4 times
# zooming: 2 times
# rigging: 4 times
# rowboat: 3 times
# rowing: 5 times
# Kraken: 19 times
# tentacles: 14 times
# distance: 7 times
# headed: 5 times
# consults: 2 times
# pouring: 2 times
# thinner: 2 times
# sewer: 1 times
# alligators: 3 times
# Hello: 40 times
# Fairly: 7 times
# styled: 6 times
# Fishface: 1 times
# Orders: 1 times
# posse: 2 times
# savoury: 12 times
# Ugh: 14 times
# itching: 1 times
# knock: 6 times
# motherfucker: 20 times
# pancake: 1 times
# style: 74 times
# friends: 41 times
# ATM: 2 times
# obviously: 11 times
# ...
# belnd: 1 times
# boosts: 1 times
# smarts: 1 times
# Noth: 1 times
# Thsss: 1 times
# mute: 1 times
# chidren: 1 times
# receptors: 1 times
# definitions: 1 times
# Stuff: 1 times
# MPEG: 1 times
# renderer: 1 times
# designMode: 1 times
# createElement: 1 times
# nonexistantfunction: 1 times
# german: 1 times
# ä: 1 times
# ö: 1 times
# begun: 1 times
# recalled: 1 times
# paypal: 1 times
# MyIE2: 1 times
# GoSuRF: 1 times
# DOCTYPE: 2 times
# biff: 1 times
# explicit: 1 times
# singular: 1 times
# Journalism: 1 times
# motivated: 1 times
# <!: 1 times
# PUBLIC: 1 times
# "-//: 1 times
# transitional: 1 times
# SearchToolbar: 1 times
# Randy: 1 times
# director: 1 times
# negro: 1 times
# molest: 1 times
# generations: 1 times
# Peng: 1 times
# reminiscin: 1 times
# counselor: 3 times
# Leaflet: 1 times
# yel: 1 times
# auuuuuuuugh: 1 times
# fatwa: 1 times
# Rikers: 1 times
# ventriloquist: 1 times
# Gawd: 1 times
# Nov: 1 times
# Apps: 2 times
# Germans: 1 times
# punish: 1 times
# gently: 1 times
# weakening: 1 times
# alps: 1 times
# Inspiron: 1 times
# 8600: 1 times
# unfocsued: 1 times
# POSIX: 1 times
# conformant: 1 times
# RDF: 2 times
# Asserts: 1 times
# nsExtensionManager: 1 times
# (-: 1 times
# Fb: 1 times
# navigates: 1 times
# 07: 1 times
# Phoenix0: 1 times
# extetion: 1 times
# secure32: 1 times
# Apply: 1 times
# unrecoverable: 1 times
# whatshisname: 1 times
# dookie: 1 times
# specially: 1 times
# noirs: 1 times
# Striking: 1 times
# worshippers: 1 times
# taget: 1 times
# Caps: 2 times
# -": 1 times
# observation: 1 times
# muthafuckas: 1 times
# glares: 1 times
# waving: 1 times
# nametag: 1 times
# shat: 1 times
# descends: 1 times
# BARBOSSA: 1 times
# ruth: 1 times
# ugliest: 2 times
# Thoughtful: 1 times
# manlier: 1 times
# Fiddler: 1 times
# Roof: 1 times
# dildos: 1 times
# Richie: 1 times
# Santorum: 1 times
# Stripper: 1 times
# Jacket: 1 times
# curiosity: 1 times
# Unclaimed: 1 times
# dine: 1 times
# fingering: 1 times
# patriot: 1 times
# executions: 1 times
# Monistat: 1 times
# Fetchez: 1 times
# vache: 1 times
# mutant: 1 times
# powers: 1 times
# reender: 1 times
# Area: 1 times
# harassment: 1 times
# icing: 1 times
# Martha: 2 times
# Parliament: 1 times
# Lights: 1 times
# tennis: 1 times
# analyst: 1 times
# Gallery: 1 times
# Minus: 1 times
# sloppy: 1 times
# wintertime: 1 times
# Fem: 1 times
# curse: 1 times
# pussies: 1 times
# Ames: 1 times
# Moby: 1 times
# Mushrooms: 1 times
# metaphysical: 1 times
# metaphorical: 1 times
# Splendidly: 1 times
# Ithaca: 1 times
# chokes: 1 times
# 214: 1 times
# DOES_NOT_EXIST: 1 times
# livemark: 2 times
# UTF8: 1 times
# feeds: 2 times
# repositions: 1 times
# carat: 1 times
# placeholder: 1 times
# SitePoint: 1 times
# executed: 1 times
# Manually: 1 times
# disable_window_open_feature: 1 times
# Elements: 1 times
# Disappear: 1 times
# spacebar: 1 times
# appeared: 1 times
# WMV: 1 times
# tariffs: 1 times
# berthing: 1 times
# fees: 1 times
# wharf: 1 times
# pilotage: 1 times
# Turnpike: 1 times
# Upgrade: 2 times
# Phase: 1 times
# timebomb: 1 times
# oversized: 1 times
# aromas: 2 times
# BdN: 1 times
# Aauuggghhh: 1 times
# debauchery: 1 times
# Emana: 1 times
# Saigon: 1 times
# Colorado: 1 times
# Faggot: 1 times
# dub: 1 times
# illustrious: 1 times
# Lancelot: 2 times
# Gallahad: 1 times
# Dragon: 2 times
# Angnor: 1 times
# Bristol: 1 times
# Badon: 1 times
# aptly: 1 times
# complained: 1 times
# Hampton: 1 times
# Prophylactic: 1 times
# Mission: 1 times
# tramp: 1 times
# %...: 1 times
# 140: 1 times
# operator: 1 times
# playa: 1 times
# hata: 1 times
# benefits: 1 times
# reasonably: 1 times
# Antigone: 1 times
# distracted: 1 times
# missionary: 1 times
# sideshow: 1 times
# getcha: 1 times
# numba: 1 times
# Douche: 1 times
# );: 1 times
# _and_: 1 times
# Crashed: 1 times
# perfoming: 1 times
# abs: 1 times
# Willy: 1 times
# Wonka: 1 times
# Huet: 1 times
# abandoned: 1 times
# Boobies: 1 times
# boobies: 2 times
# 41st: 1 times
# planned: 1 times
# Chimapate: 1 times
# courageous: 1 times
# Pasties: 1 times
# Aids: 1 times
# blondes: 1 times
# brunettes: 1 times
# protect: 1 times
# silliness: 1 times
# Init: 1 times
# visable: 1 times
# Frogpad: 1 times
# Westpac: 1 times
# funds: 1 times
# Resized: 1 times
# spends: 1 times
# Cursive: 1 times
# Fantasy: 1 times
# 03: 2 times
# domainMismatch: 1 times
# switchable: 1 times
# TitleBar: 1 times
# WindowsXP: 1 times
# requst: 1 times
# nearer: 1 times
# Gorge: 1 times
# Eternal: 1 times
# Peril: 1 times
# SJP: 1 times
# Vincent: 1 times
# appendicitis: 1 times
# remake: 1 times
# bicycles: 1 times
# echoed: 1 times
# 610: 1 times
# ranges: 1 times
# scope: 1 times
# Part: 1 times
# Localize: 1 times
# FE: 1 times
# costumes: 1 times
# fetish: 1 times
# sickness: 1 times
# Touristy: 1 times
# combining: 1 times
# tautness: 1 times
# SALE: 1 times
# Leathery: 1 times
# prettiest: 1 times
# Tripoli: 1 times
# babymomma: 1 times
# Anton: 1 times
# Webern: 1 times
# Quartet: 1 times
# inviting: 1 times
# kiddin: 1 times
# paycheck: 1 times
# shark: 2 times
# underpinning: 1 times
# cone: 1 times
# babes: 1 times
# refugee: 1 times
# chapter: 1 times
# Harrison: 1 times
# Ford: 1 times
# uuup: 1 times
# afoot: 1 times
# Jerk: 1 times
# frothy: 1 times
# Approachable: 1 times
# 72nd: 2 times
# Bored: 2 times
# 178cm: 1 times
# 79kg: 1 times
# reclassified: 1 times
# Robinson: 1 times
# druggies: 1 times
# mindless: 1 times
# drones: 1 times
# sympathy: 1 times
# rainbows: 1 times
# loos: 1 times
# pdfs: 1 times
# Locks: 1 times
# dialup: 1 times
# athlon: 1 times
# optimation: 1 times
# seg: 1 times
# OpenURL: 1 times
# MEDIA: 1 times
# LINK: 1 times
# lis: 1 times
# KlipArt: 1 times
# firstusa: 1 times
# shrugging: 1 times
# ],: 1 times
# chemical: 1 times
# legos: 1 times
# dynamics: 1 times
# stew: 1 times
# Champenois: 1 times
# idiosynchratic: 1 times
# SCARLETT: 1 times
# luckiest: 1 times
# suits: 1 times
# apologise: 1 times
# extravagently: 1 times
# flatness: 1 times
# tagged: 1 times
# teamed: 1 times
# Notably: 1 times
# voom: 1 times
# Combe: 1 times
# aux: 1 times
# Moins: 1 times
# mofo: 1 times
# JT: 1 times
# Leroy: 1 times
# Himalayas: 1 times
# scott: 1 times
# dollahs: 1 times
# liquoricey: 1 times
# disjoint: 1 times
# dialysis: 1 times
# LanguagePacks: 1 times
# lock_pref: 1 times
# impose: 1 times
# Jong: 1 times
# il: 1 times
# Crackheads: 1 times
# coupla: 1 times
# eyepatch: 1 times
# Twink: 1 times
# pounding: 2 times
# bonfire: 1 times
# Proceededly: 1 times
# Water: 1 times
# Reminder: 1 times
# eighties: 1 times
# Clarets: 1 times
# infants: 1 times
# eighteen: 1 times
# syrah: 1 times
# knuckles: 2 times
# Guyy: 1 times
# Graham: 1 times
# reward: 1 times
# Duane: 2 times
# Reade: 2 times
# attacks: 1 times
# lettin: 1 times
# ree: 1 times
# dahs: 1 times
# contagious: 1 times
# Weren: 1 times
# FEISTY: 1 times
# FOXY: 1 times
# YUMMY: 1 times
# GRANDMUMMY: 1 times
# Laundromat: 1 times
# sardines: 1 times
# Lockup: 1 times
# remarks: 1 times
# Semi: 1 times
# attempted: 1 times
# iconize: 1 times
# workingon: 1 times
# Listerine: 1 times
# warned: 1 times
# onmouseout: 1 times
# executres: 1 times
# R3DM24: 1 times
# Vanillan: 1 times
# nuisance: 1 times
# Arab: 1 times
# gyne: 1 times
# Contemplated: 1 times
# BYO: 1 times
# decorated: 1 times
# cocksucker: 1 times
# Sprite: 1 times
# subliminal: 1 times
# averting: 1 times
# bumps: 1 times
# Designs: 1 times
# impaled: 1 times
# bob: 1 times
# harassed: 1 times
# Welch: 1 times
# brighter: 1 times
# carousel: 1 times
# Powerful: 2 times
# Hovers: 1 times
# trenitalia: 1 times
# checkmark: 1 times
# centering: 1 times
# leftarrow: 1 times
# throb: 1 times
# dotted: 2 times
# fins: 1 times
# typeahead: 1 times
# rmvplus: 1 times
# Logs: 1 times
# mplayerplug: 1 times
# nighly: 1 times
# national: 1 times
# Urinal: 1 times
# Hoo: 2 times
# Asked: 1 times
# fetching: 1 times
# facicon: 1 times
# populated: 1 times
# PgUp: 1 times
# mob: 1 times
# Inferior: 1 times
# Drawn: 1 times
# Correctly: 1 times
# gstreamer: 1 times
# Hover: 1 times
# Customizable: 2 times
# Cramped: 1 times
# MapQuest: 1 times
# Bones: 1 times
# strewn: 1 times
# lair: 1 times
# Yikes: 1 times
# Nutty: 1 times
# mainstream: 1 times
# SRC: 1 times
# freezed: 1 times
# funcion: 1 times
# bluescreen: 1 times
# WMZ: 1 times
# Canvas9: 1 times
# generate: 3 times
# gametimesonline: 1 times
# freezez: 1 times
# 65MB: 1 times
# signaling: 1 times
# disorders: 1 times
# digger: 1 times
# headjobs: 1 times
# negotiator: 1 times
# canteen: 1 times
# camouflaged: 2 times
# yanked: 1 times
# snare: 1 times
# dangles: 1 times
# hence: 1 times
# freezer: 1 times
# cleavage: 1 times
# Dartmouth: 2 times
# Tina: 1 times
# nonstandard: 1 times
# FedEx: 1 times
# Weijing: 1 times
# Delicate: 1 times
# grovel: 1 times
# courthouse: 1 times
# phobia: 1 times
# FAO: 1 times
# Schwarz: 1 times
# Tastes: 1 times
# dawg: 1 times
# feeble: 1 times
# libnkgnomevfs: 1 times
# libnegotiateauth: 1 times
# completly: 1 times
# patting: 1 times
# picket: 1 times
# Executing: 1 times
# openurl: 2 times
# crowds: 1 times
# pincher: 1 times
# spoken: 1 times
# Cinco: 1 times
# Mayo: 1 times
# Thirty: 2 times
# SYRAH: 1 times
# accompaniment: 1 times
# dishes: 1 times
# flavoured: 1 times
# vegans: 1 times
# effortlessly: 1 times
# Nutley: 1 times
# dancers: 1 times
# pronoun: 1 times
# hereby: 1 times
# Magician: 1 times
# taping: 1 times
# distant: 1 times
# Maureen: 1 times
# Dowd: 1 times
# Loco: 1 times
# 52nd: 1 times
# yadda: 3 times
# Progresso: 1 times
# Parkinson: 1 times
# sucker: 1 times
# Coughing: 1 times
# wheezing: 1 times
# Grinch: 1 times
# Stole: 1 times
# Else: 1 times
# Face: 1 times
# compel: 1 times
# Technicolor: 1 times
# Dreamcoat: 1 times
# rainbow: 1 times
# DTD: 1 times
# GPF: 1 times
# Mousover: 1 times
# subwindows: 1 times
# backward: 1 times
# faint: 1 times
# TiVoed: 1 times
# wheelbarrow: 1 times
# Goliath: 1 times
# tendency: 1 times
# spatlese: 1 times
# ESPN: 1 times
# Cougar: 1 times
# Training: 1 times
# partygoers: 1 times
# Genius: 1 times
# movable: 1 times
# verca: 1 times
# PgDn: 1 times
# recognizeable: 1 times
# Evangelism: 1 times
# MBNA: 1 times
# Payment: 1 times
# recognizes: 1 times
# nsSidebar: 1 times
# polished: 1 times
# Chile: 1 times
# Footland: 1 times
# clouds: 1 times
# luncheons: 1 times
# indoor: 1 times
# bowls: 1 times
# Heart: 2 times
# aching: 1 times
# Blows: 1 times
# enthusiastically: 1 times
# stowaway: 1 times
# Pantano: 2 times
# longboats: 2 times
# swampy: 1 times
# Blondie: 1 times
# hungrier: 1 times
# regret: 1 times
# Sth: 1 times
# proves: 1 times
# scuttles: 1 times
# crunches: 1 times
# revulsion: 1 times
# forestall: 1 times
# intercepts: 1 times
# Technic: 1 times
# Macon: 1 times
# Penguins: 1 times
# Ginka: 1 times
# balinka: 1 times
# Terminator: 1 times
# Muslims: 1 times
# nighttime: 1 times
# hatch: 1 times
# sneaks: 2 times
# quill: 1 times
# staves: 1 times
# unappetising: 1 times
# WEATHERED: 1 times
# hazelnut: 1 times
# conceited: 1 times
# ..?: 1 times
# Networking: 1 times
# hunters: 1 times
# Rhodium: 1 times
# hysterical: 1 times
# Embassy: 1 times
# nonempty: 1 times
# touristy: 1 times
# Reductive: 1 times
# 78: 1 times
# Reliable: 1 times
# Ridge: 1 times
# briochey: 1 times
# Charms: 1 times
# Marriott: 1 times
# abuse: 1 times
# Mix: 1 times
# wth: 1 times
# rightclicking: 1 times
# desensitizing: 1 times
# gerbil: 1 times
# API: 1 times
# hilitecolor: 1 times
# backcolor: 1 times
# correction: 1 times
# exaggerates: 1 times
# mingw: 1 times
# brwsrcmp: 1 times
# beetrooty: 1 times
# insofar: 1 times
# shallows: 1 times
# aerodynamic: 1 times
# magicians: 1 times
# landed: 1 times
# fetid: 1 times
# suggestin: 1 times
# Lovitz: 2 times
# Jealous: 1 times
# Buckingham: 1 times
# sharks: 1 times
# varletesses: 1 times
# cuuuuuuuuuute: 1 times
# medal: 1 times
# untill: 1 times
# strlen: 1 times
# README: 1 times
# TXT: 1 times
# mentions: 1 times
# lexis: 2 times
# 225755: 1 times
# -<: 1 times
# Contract: 1 times
# Blake: 1 times
# allways: 1 times
# sweets: 1 times
# Wha: 1 times
# Boogers: 1 times
# retreat: 1 times
# emperor: 1 times
# moistened: 1 times
# bint: 1 times
# lobbed: 1 times
# scimitar: 1 times
# Liquid: 1 times
# footstep: 1 times
# gooseneck: 1 times
# barnacles: 1 times
# retract: 1 times
# Mud: 1 times
# slingshot: 1 times
# catheters: 1 times
# solve: 1 times
# Firebox: 1 times
# martin: 1 times
# plover: 1 times
# climes: 1 times
# inquire: 1 times
# viagra: 1 times
# Sherry: 1 times
# Shrubber: 1 times
# Nancy: 1 times
# Bass: 1 times
# Colheitas: 1 times
# 00: 1 times
# poisoning: 2 times
# handicap: 1 times
# Appetising: 1 times
# reaching: 1 times
# monstrous: 1 times
# Fraaaaan: 1 times
# Mhm: 1 times
# sassy: 1 times
# hoodie: 1 times
# prayed: 1 times
# cube: 1 times
# nnniggets: 1 times
# Snobby: 1 times
# chilli: 1 times
# prawns: 1 times
# Frameset: 1 times
# wacked: 1 times
# blockup: 1 times
# popper: 1 times
# exclude: 1 times
# Additional: 1 times
# Enhancements: 1 times
# MOZILLA_OFFICIAL: 1 times
# BUILD_OFFICIAL: 1 times
# wishlist: 1 times
# zoon: 1 times
# /-: 1 times
# segment: 1 times
# Consistently: 1 times
# stalk: 1 times
# Air: 1 times
# Pfft: 1 times
# Zach: 1 times
# Gulman: 2 times
# shoves: 1 times
# EasyWeb: 1 times
# recreation: 1 times
# Flag: 1 times
# "|": 1 times
# Dlg: 1 times
# execute: 1 times
# minimizing: 1 times
# Breed: 1 times
# fore: 1 times
# intercontinental: 1 times
# messenger: 1 times
# stead: 1 times
# Bors: 1 times
# Secmod: 1 times
# db: 1 times
# migrated: 1 times
# closebuttons: 1 times
# LAYOUT: 1 times
# tracked: 1 times
# Importing: 1 times
# nightbuilds: 1 times
# Groups: 1 times
# Beta: 1 times
# SEI: 1 times
# nonsmoker: 1 times
# Pineappley: 1 times
# ANIMATOR: 1 times
# Ulk: 1 times
# potential: 2 times
# softy: 1 times
# Dichotomy: 1 times
# pitchfork: 1 times
# Doc: 1 times
# Holliday: 1 times
# sewing: 1 times
# mmore: 1 times
# Perret: 1 times
# sudo: 1 times
# eposasp: 1 times
# ebpp: 1 times
# holder: 1 times
# MANAGE: 1 times
# BOOKMARKS: 1 times
# unpredictable: 1 times
# GData: 1 times
# Endnote: 2 times
# cease: 1 times
# Updates: 1 times
# trusty: 1 times
# weeed: 1 times
# CRAZZZYYYY: 1 times
# nada: 1 times
# zilch: 1 times
# capris: 1 times
# FF10x: 1 times
# WMP9: 1 times
# wmp: 2 times
# 0x56ff8b90: 1 times
# INPUTs: 1 times
# Ciphers: 1 times
# Unify: 1 times
# nsXREDirProvider: 1 times
# nsProfileMigrator: 1 times
# Gnome: 1 times
# populate: 1 times
# apostrope: 1 times
# WINDOWS: 1 times
# upgrades: 1 times
# wiped: 1 times
# sarin: 1 times
# summery: 1 times
# hips: 1 times
# Victorian: 1 times
# Soda: 1 times
# Vanderbilt: 1 times
# Belarus: 1 times
# seasonally: 1 times
# frazzled: 1 times
# Cellmate: 1 times
# maximizes: 1 times
# clips: 1 times
# Strawberries: 1 times
# yeastiness: 1 times
# Riiight: 1 times
# bohemian: 1 times
# Pseudo: 1 times
# lowercase: 1 times
# executables: 1 times
# Oo: 1 times
# Deutz: 1 times
# PhD: 1 times
# Simone: 1 times
# Nation: 1 times
# Allways: 1 times
# pl: 1 times
# Clarify: 1 times
# fest: 1 times
# hyphenation: 1 times
# 173: 1 times
# Chrome: 1 times
# Loops: 1 times
# Rockettes: 1 times
# dolls: 1 times
# bandstand: 1 times
# drummers: 1 times
# Scarves: 1 times
# lice: 1 times
# opinions: 1 times
# dominatrix: 1 times
# wimp: 1 times
# Bermuda: 1 times
# wedgie: 1 times
# poopie: 1 times
# PowerBar: 1 times
# Meatier: 1 times
# breeze: 1 times
# sacrificing: 1 times
# Maboogie: 1 times
# snickel: 2 times
# eyeliner: 1 times
# skips: 1 times
# settles: 1 times
# Ridden: 1 times
# bougie: 1 times
# ....[: 1 times
# redials: 1 times
# Maria: 1 times
# October: 1 times
# raving: 1 times
# robotic: 1 times
# supple: 1 times
# jaundice: 1 times
# handbags: 1 times
# ANTIDOTE: 1 times
# tv: 1 times
# DIRECTOR: 1 times
# Future: 1 times
# politician: 1 times
# HOW: 1 times
# Deeper: 1 times
# ravishing: 1 times
# CITY: 1 times
# GIRL: 1 times
# SEEKS: 1 times
# ROMANCE: 1 times
# htis: 1 times
# Adress: 1 times
# Adressbar: 1 times
# adressbar: 1 times
# TABS: 1 times
# Pepsi: 1 times
# honeymoon: 1 times
# Secret: 1 times
# hijacked: 1 times
# studied: 1 times
# carefully: 1 times
# bleeds: 1 times
# Optional: 1 times
# advert: 1 times
# Segfault: 1 times
# libimglib2: 1 times
# modules: 1 times
# Parnell: 1 times
# Liar: 1 times
# stench: 1 times
# capsized: 1 times
# tinged: 1 times
# summarily: 1 times
# treacle: 1 times
# autoupdating: 1 times
# Tablet: 1 times
# tablet: 1 times
# 542: 1 times
# 927: 1 times
# Yodas: 1 times
# Homeland: 1 times
# stoked: 1 times
# Waits: 1 times
# underestimate: 1 times
# Monaco: 1 times
# Venkman: 1 times
# debugger: 1 times
# ratified: 1 times
# weekly: 1 times
# upholds: 1 times
# deadman: 1 times
# annihilated: 1 times
# omigod: 1 times
# spills: 1 times
# stronger: 1 times
# revisit: 1 times
# inking: 1 times
# fadder: 1 times
# bidding: 1 times
# mng: 1 times
# Viognier: 1 times
# contemplatively: 1 times
# Pittsburgh: 1 times
# Frames: 1 times
# linuxinsider: 1 times
# 225239: 1 times
# expletive: 1 times
# annual: 1 times
# Quitelarge: 1 times
# sooner: 1 times
# EMPLOYED: 1 times
# haired: 1 times
# 41: 1 times
# furthermore: 1 times
# Cigar: 1 times
# gallows: 1 times
# Vampire: 1 times
# Ozzie: 1 times
# unozzie: 1 times
# Shithaca: 1 times
# Racquet: 1 times
# shoelaces: 1 times
# sandal: 1 times
# dystrophy: 1 times
# Weirdo: 1 times
# Tunina: 1 times
# spouse: 1 times
# Barbados: 2 times
# wheelchairs: 1 times
# mistook: 1 times
# alleged: 1 times
# screening: 1 times
# inbetween: 1 times
# weightiness: 1 times
# alleviate: 1 times
# 31st: 1 times
# AString: 1 times
# qute: 1 times
# Palm: 1 times
# itâ: 1 times
# x2122: 1 times
# trau: 1 times
# mutilates: 1 times

# %% [markdown]
# We will keep words found more than 10 times in our corpus to create our vocabulary

# %%
filtered_words = {word: freq for word, freq in word_freq.items() if freq > 10}
vocabulary = filtered_words.keys()
vocabulary = list(vocabulary)
vocabulary.append('<e>')
vocabulary[:10]
# Out:
# ['***', 'Very', 'fine', ',', 'elegant', 'balanced', '.', 'Mother', ':', 'No']

# %% [markdown]
# We create the function replace_oov_with_unk to replace all the out-of-vocabulary-words of our training and test sets with the special token **UNK**.

# %%
def replace_oov_with_unk(vocabulary, sentences):
    replaced_sentences = []

    for sentence in sentences:
        replaced_sentence = [word if word in vocabulary else "*UNK*" for word in sentence]
        replaced_sentences.append(replaced_sentence)

    return replaced_sentences

# %%
train_set_2 = replace_oov_with_unk(vocabulary, train_set)
train_set_2[:3]
# Out:
# [['***', 'Very', 'fine', ',', 'elegant', ',', '*UNK*', ',', 'balanced', '.'],
#  ['Mother',
#   ':',
#   'No',
#   'way',
#   '...',
#   'She',
#   'is',
#   'singing',
#   'into',
#   'the',
#   'saw',
#   '?'],
#  ['Not',
#   'Rated',
#   'Very',
#   'light',
#   'and',
#   '*UNK*',
#   '-',
#   'decent',
#   'but',
#   'a',
#   'bit',
#   '*UNK*',
#   '.']]

# %%
test_set_2 = replace_oov_with_unk(vocabulary, test_set)
test_set_2[:3]
# Out:
# [['and', 'looking', 'for', '*UNK*', '/', 'friendship', '.'],
#  ['And',
#   'here',
#   'in',
#   '*UNK*',
#   '*UNK*',
#   ',',
#   'we',
#   'have',
#   'but',
#   'one',
#   '*UNK*',
#   'for',
#   'setting',
#   '*UNK*',
#   'the',
#   '*UNK*',
#   '-',
#   '*UNK*',
#   '*UNK*',
#   '.'],
#  ['FATHER', ':', 'Right', '.']]

# %% [markdown]
# Below we train our ngram models (unigram, bigram and trigram) and print the 5 most frequent word combinations of each model.

# %%
from collections import Counter
from nltk.util import ngrams
import pprint

N = 5

unigram_counter = Counter()
bigram_counter = Counter()
trigram_counter = Counter()

for sent in train_set_2:
    unigram_counter.update([gram for gram in ngrams(sent, 1, pad_left=True, pad_right=True,
                                                   left_pad_symbol='<s>',right_pad_symbol='<e>') ])
    bigram_counter.update([gram for gram in ngrams(sent, 2, pad_left=True, pad_right=True,
                                                   left_pad_symbol='<s>',right_pad_symbol='<e>') ])
    trigram_counter.update([gram for gram in ngrams(sent, 3, pad_left=True, pad_right=True,
                                                   left_pad_symbol='<s>',right_pad_symbol='<e>') ])

# %%
print("Most Frequent Unigrams:")    
print(unigram_counter.most_common(N))
print("------------------------------------------------")
print("Most Frequent Bigrams:") 
print(bigram_counter.most_common(N))
print("------------------------------------------------")
print("Most Frequent Trigrams:") 
print(trigram_counter.most_common(N))
# Out:
# Most Frequent Unigrams:
# [(('*UNK*',), 37459), (('.',), 14194), ((':',), 11335), ((',',), 9850), (("'",), 8632)]
# ------------------------------------------------
# Most Frequent Bigrams:
# [(('.', '<e>'), 12872), (('*UNK*', '*UNK*'), 5230), (('*UNK*', '.'), 4073), (('?', '<e>'), 3477), (('!', '<e>'), 3255)]
# ------------------------------------------------
# Most Frequent Trigrams:
# [(('.', '<e>', '<e>'), 12872), (('*UNK*', '.', '<e>'), 3701), (('?', '<e>', '<e>'), 3477), (('!', '<e>', '<e>'), 3255), (('<s>', '<s>', '*UNK*'), 2979)]

# %% [markdown]
# ## Bigram and Trigram Cross Entropy and Perplexity

# %% [markdown]
# We calculate our bigrams LM Cross Entropy and Perplexity, using Laplace a-smoothing (a = 0.001) for the calculations of the bigram probabilities. We also ignore the probabilities including the start token (P(*start*|…)).

# %%
import math
from itertools import pairwise

alpha = 0.001
vocab_size = len(set(vocabulary))
sum_prob = 0
bigram_cnt = 0

for sent in test_set_2:
    sent = ['<s>'] + sent + ['<e>']
    for first_token, second_token in pairwise(sent):
        bigram_prob = (bigram_counter[(first_token, second_token)] + alpha) / (unigram_counter[(first_token,)] + alpha*vocab_size)
        sum_prob += math.log2(bigram_prob)
        bigram_cnt += 1

HC = -sum_prob / bigram_cnt
perpl = math.pow(2, HC)
print("Cross Entropy: {0:.3f}".format(HC))
print("perplexity: {0:.3f}".format(perpl))
# Out:
# Cross Entropy: 5.366
# perplexity: 41.253

# %% [markdown]
# We do the same for our trigram model ignoring again P(*start1*|…), P(*start2*|…).

# %%
from more_itertools import windowed

sum_prob = 0
trigram_cnt = 0

for sent in test_set_2:
    sent = ['<s>'] + ['<s>'] + sent + ['<e>']

    for first_token, second_token, third_token in windowed(sent, n=3):
        trigram_prob = (trigram_counter[(first_token, second_token, third_token)] + alpha) / (bigram_counter[(first_token, second_token)] + alpha*vocab_size)
        sum_prob += math.log2(trigram_prob)
        trigram_cnt+=1

HC = -sum_prob / trigram_cnt
perpl = math.pow(2,HC)
print("Cross Entropy: {0:.3f}".format(HC))
print("perplexity: {0:.3f}".format(perpl))
# Out:
# Cross Entropy: 6.351
# perplexity: 81.629

# %% [markdown]
# ## Text Auto-Completion

# %% [markdown]
# Below we include code that generates the most probable next words, using our bigram and trigram frequencies, to complete the missing words of a sentence.

# %%
def generate_candidates_bi(state):
    # Given state , generate possible next words
    last_word = state[-1]
    next_words = [word for (prev_word, word) in bigram_counter if prev_word == last_word]
    my_list = [state + [next_word] for next_word in next_words]
    return my_list

def generate_candidates_tri(state):
    # Given state , generate possible next words
    last_word = state[-1]
    last_2_word = state[-2]
    next_words = [word for (prev_2_word, prev_word, word) in trigram_counter if (prev_word == last_word and prev_2_word == last_2_word)]
    my_list = [state + [next_word] for next_word in next_words]
    return my_list

def score_bi(state):
    # Calculate the probability of the word sequence using the bigram model
    probability = 0.0
    for i in range(1, len(state)):
        prev_word, word = state[i-1], state[i]
        probability += math.log2(bigram_counter.get((prev_word, word), 0.0) + 0.001)
    return probability

def score_tri(state):
    # Calculate the probability of the word sequence using the bigram model
    probability = 0.0
    for i in range(2, len(state)):
        prev_2_word, prev_word, word = state[i-2],state[i-1], state[i]
        probability += math.log2(trigram_counter.get((prev_2_word, prev_word, word), 0.0) + 0.001)
    return probability

def beam_search_decode(initial_state, max_depth, beam_width, generate_candidates_fn, score_fn):
    candidates = [(initial_state, 0.0)]
    string_to_ignore = "*UNK*"
    
    for depth in range(max_depth):
        new_candidates = []
        for candidate, prob in candidates:
            for next_state in generate_candidates_fn(candidate):
                if string_to_ignore in next_state:
                    continue
                else:
                    new_prob = prob + score_fn(next_state)
                    new_candidates.append((next_state, new_prob))

        new_candidates = sorted(new_candidates, key=lambda x: x[1], reverse=True)
        '''print('\n***** NEW candidates *****')
        pprint(new_candidates)
        new_candidates = sorted(new_candidates, key=lambda x: x[1], reverse=True)
        pprint('***** Sorted')
        pprint(new_candidates)'''
        print(f'***** Chosen candidates (top-{beam_width})')
        candidates = new_candidates[:beam_width]
        print(candidates)

    best_sequence, best_prob = max(candidates, key=lambda x: x[1])
    return best_sequence

# %% [markdown]
# ### Bigram auto-completion example

# %%
initial_state = "<s> try to help"
initial_state = initial_state.split()
max_depth = 15
beam_width = 2
best_sequence = beam_search_decode(initial_state, max_depth, beam_width, generate_candidates_bi, score_bi)

print("Best sequence:", best_sequence[1:])  # Excluding the "<start>" token
# Out:
# ***** Chosen candidates (top-2)
# [(['<s>', 'try', 'to', 'help', 'me'], 2.9966432875315396), (['<s>', 'try', 'to', 'help', 'you'], 2.20820261153887)]
# ***** Chosen candidates (top-2)
# [(['<s>', 'try', 'to', 'help', 'me', '.'], 13.25068384710427), (['<s>', 'try', 'to', 'help', 'me', ','], 12.838789171127178)]
# ***** Chosen candidates (top-2)
# [(['<s>', 'try', 'to', 'help', 'me', '.', '<e>'], 37.15667312948054), (['<s>', 'try', 'to', 'help', 'me', ',', 'I'], 32.68375147646471)]
# ***** Chosen candidates (top-2)
# [(['<s>', 'try', 'to', 'help', 'me', ',', 'I', "'"], 62.908093231977475), (['<s>', 'try', 'to', 'help', 'me', ',', 'I', 'don'], 61.24981638921399)]
# ***** Chosen candidates (top-2)
# [(['<s>', 'try', 'to', 'help', 'me', ',', 'I', "'", 't'], 104.5821000417672), (['<s>', 'try', 'to', 'help', 'me', ',', 'I', "'", 's'], 104.46447209546972)]
# ***** Chosen candidates (top-2)
# [(['<s>', 'try', 'to', 'help', 'me', ',', 'I', "'", 's', 'a'], 153.78240883975536), (['<s>', 'try', 'to', 'help', 'me', ',', 'I', "'", 't', 'know'], 153.7479679628368)]
# ***** Chosen candidates (top-2)
# [(['<s>', 'try', 'to', 'help', 'me', ',', 'I', "'", 't', 'know', ','], 210.38144958478583), (['<s>', 'try', 'to', 'help', 'me', ',', 'I', "'", 's', 'a', 'bit'], 210.3577428560822)]
# ***** Chosen candidates (top-2)
# [(['<s>', 'try', 'to', 'help', 'me', ',', 'I', "'", 't', 'know', ',', 'I'], 277.01774762847674), (['<s>', 'try', 'to', 'help', 'me', ',', 'I', "'", 't', 'know', ',', 'but'], 275.9662188362343)]
# ***** Chosen candidates (top-2)
# [(['<s>', 'try', 'to', 'help', 'me', ',', 'I', "'", 't', 'know', ',', 'I', "'"], 354.03342512234286), (['<s>', 'try', 'to', 'help', 'me', ',', 'I', "'", 't', 'know', ',', 'I', 'don'], 352.37514827957943)]
# ***** Chosen candidates (top-2)
# [(['<s>', 'try', 'to', 'help', 'me', ',', 'I', "'", 't', 'know', ',', 'I', "'", 't'], 442.49876767048596), (['<s>', 'try', 'to', 'help', 'me', ',', 'I', "'", 't', 'know', ',', 'I', "'", 's'], 442.3811397241885)]
# ***** Chosen candidates (top-2)
# [(['<s>', 'try', 'to', 'help', 'me', ',', 'I', "'", 't', 'know', ',', 'I', "'", 's', 'a'], 538.4904122068275), (['<s>', 'try', 'to', 'help', 'me', ',', 'I', "'", 't', 'know', ',', 'I', "'", 't', 'know'], 538.455971329909)]
# ***** Chosen candidates (top-2)
# [(['<s>', 'try', 'to', 'help', 'me', ',', 'I', "'", 't', 'know', ',', 'I', "'", 't', 'know', ','], 641.8807886902114), (['<s>', 'try', 'to', 'help', 'me', ',', 'I', "'", 't', 'know', ',', 'I', "'", 's', 'a', 'bit'], 641.8570819615077)]
# ***** Chosen candidates (top-2)
# [(['<s>', 'try', 'to', 'help', 'me', ',', 'I', "'", 't', 'know', ',', 'I', "'", 't', 'know', ',', 'I'], 755.3084224722556), (['<s>', 'try', 'to', 'help', 'me', ',', 'I', "'", 't', 'know', ',', 'I', "'", 't', 'know', ',', 'but'], 754.2568936800133)]
# ***** Chosen candidates (top-2)
# [(['<s>', 'try', 'to', 'help', 'me', ',', 'I', "'", 't', 'know', ',', 'I', "'", 't', 'know', ',', 'I', "'"], 879.1154357044752), (['<s>', 'try', 'to', 'help', 'me', ',', 'I', "'", 't', 'know', ',', 'I', "'", 't', 'know', ',', 'I', 'don'], 877.4571588617117)]
# ***** Chosen candidates (top-2)
# [(['<s>', 'try', 'to', 'help', 'me', ',', 'I', "'", 't', 'know', ',', 'I', "'", 't', 'know', ',', 'I', "'", 't'], 1014.3721139909717), (['<s>', 'try', 'to', 'help', 'me', ',', 'I', "'", 't', 'know', ',', 'I', "'", 't', 'know', ',', 'I', "'", 's'], 1014.2544860446742)]
# Best sequence: ['try', 'to', 'help', 'me', ',', 'I', "'", 't', 'know', ',', 'I', "'", 't', 'know', ',', 'I', "'", 't']

# %% [markdown]
# ### Trigram auto-completion example

# %%
initial_state = "<s> <s> try to help"
initial_state = initial_state.split()
max_depth = 6
beam_width = 2
best_sequence = beam_search_decode(initial_state, max_depth, beam_width, generate_candidates_tri, score_tri)

print("Best sequence:", best_sequence[1:])  # Excluding the "<start>" token
# Out:
# ***** Chosen candidates (top-2)
# [(['<s>', '<s>', 'try', 'to', 'help', 'you'], -28.89663168674261), (['<s>', '<s>', 'try', 'to', 'help', ','], -28.89663168674261)]
# ***** Chosen candidates (top-2)
# [(['<s>', '<s>', 'try', 'to', 'help', 'you', '?'], -56.20782005454902), (['<s>', '<s>', 'try', 'to', 'help', 'you', 'with'], -56.79254220624156)]
# ***** Chosen candidates (top-2)
# [(['<s>', '<s>', 'try', 'to', 'help', 'you', '?', '<e>'], -77.23358770752148), (['<s>', '<s>', 'try', 'to', 'help', 'you', 'with', 'anything'], -84.68701075156662)]
# ***** Chosen candidates (top-2)
# [(['<s>', '<s>', 'try', 'to', 'help', 'you', '?', '<e>', '<e>'], -86.49572759384114), (['<s>', '<s>', 'try', 'to', 'help', 'you', 'with', 'anything', 'else'], -112.58003732271776)]
# ***** Chosen candidates (top-2)
# [(['<s>', '<s>', 'try', 'to', 'help', 'you', 'with', 'anything', 'else', '.'], -138.8876205749327), (['<s>', '<s>', 'try', 'to', 'help', 'you', 'with', 'anything', 'else', '?'], -140.471621919695)]
# ***** Chosen candidates (top-2)
# [(['<s>', '<s>', 'try', 'to', 'help', 'you', 'with', 'anything', 'else', '.', '<e>'], -161.7356410603769), (['<s>', '<s>', 'try', 'to', 'help', 'you', 'with', 'anything', 'else', '?', '<e>'], -166.77776319773602)]
# Best sequence: ['<s>', 'try', 'to', 'help', 'you', 'with', 'anything', 'else', '.', '<e>']

# %% [markdown]
# ##  Context-aware spelling corrector

# %% [markdown]
# We used our ngram models and the normalized Levenshtein edit distance measure, to predict which is the actual word the user meant to type, for each word of a sentence. Specifically, the word chosen was the one that minimized: -log2P(bigram or trigram probability of word with previous words selected) + log2(edit distance of actual word with candidate word). All words of the vocabulary are checked as candidates each time and a beam search method is used that, for each step, selects the top 2 candidates that minimize the score shown above. That way for each word of the mispelled sentence, the top 2 candidates are selected and in the final step the best scored sentence is choosed. We us l1, l2 to balance the importance of the two factors (bigram prob and edit distance) and tune them to get better performance.

# %%
import Levenshtein
from itertools import product

def normalize_dict(original_dict):
    # Extract values from the dictionary
    values = list(original_dict.values())

    # Calculate min and max values
    min_value = min(values)
    max_value = max(values)

    # Normalize each value in the dictionary
    normalized_dict = {key: (value - min_value) / (max_value - min_value) for key, value in original_dict.items()}

    return normalized_dict

def generate_candidates_levenshtein_bi(state,word_list):
    # Given state , generate possible next words
    last_word = state[-1]
    distances = {(word, voc_token):Levenshtein.distance(word, voc_token) for word, voc_token in product(word_list, vocabulary)}
    next_words = [word for (prev_word, word) in bigram_counter if prev_word == last_word]
    return [state + [next_word] for next_word in next_words], distances

def score_levenshtein_bi(state,distance):
    l1 = 0.4
    l2 = 0.6
    probability = 0.0
    for i in range(1, len(state)):
        prev_word, word = state[i-1], state[i]
        bigram_prob = (bigram_counter[(prev_word, word)] + 0.001) / (unigram_counter[(prev_word,)] + 0.001*vocab_size)
        probability += -l1*math.log2(bigram_prob) + l2*math.log2(distance + 0.001)
    return probability


def beam_search_decode(initial_state, max_depth, beam_width, generate_candidates_fn, score_fn,word_list):
    candidates = [(initial_state, 0.0)]
    string_to_ignore = "*UNK*"
    string_to_ignore_2 = "<e>"
    
    j=0
    for depth in range(max_depth):
        new_candidates = []
        for candidate, prob in candidates:
            next_state,distances = generate_candidates_fn(candidate,word_list)
            distances = normalize_dict(distances)
            for i,_ in enumerate(next_state):
                if (string_to_ignore in next_state[i]) or (string_to_ignore_2 in next_state[i]):
                    continue
                else:
                    new_prob = prob + score_fn(next_state[i],distances[(word_list[j],next_state[i][-1])])
                    new_candidates.append((next_state[i], new_prob))
        j += 1

        new_candidates = sorted(new_candidates, key=lambda x: x[1], reverse=False)
        candidates = new_candidates[:beam_width]
    if candidates == []:
        best_sequence = []
        return best_sequence 
    best_sequence, best_prob = min(candidates, key=lambda x: x[1])
    return best_sequence

# %% [markdown]
# ### Type 1 error example (wrong spelling)

# %%
word_list_1st_type = 'Noot Rted Ver ligt'
word_list_1st_type = word_list_1st_type.split()
word_list_1st_type
# Out:
# ['Noot', 'Rted', 'Ver', 'ligt']

# %% [markdown]
# ### Type 2 error example (logical error)

# %%
word_list_2nd_type = 'He is going two the class'
word_list_2nd_type = word_list_2nd_type.split()
word_list_2nd_type
# Out:
# ['He', 'is', 'going', 'two', 'the', 'class']

# %% [markdown]
# ### Bigram spelling corrector examples

# %%
initial_state = "<s>"
initial_state = initial_state.split()
max_depth = 4
beam_width = 2
best_sequence_1 = beam_search_decode(initial_state, max_depth, beam_width, generate_candidates_levenshtein_bi, score_levenshtein_bi,word_list_1st_type)
print("Best sequence:", best_sequence_1[1:])  # Excluding the "<start>" token
max_depth = 6
best_sequence_2 = beam_search_decode(initial_state, max_depth, beam_width, generate_candidates_levenshtein_bi, score_levenshtein_bi,word_list_2nd_type)
print("Best sequence:", best_sequence_2[1:])  # Excluding the "<start>" token
# Out:
# Best sequence: ['Not', 'Rated', 'Very', 'light']
# Best sequence: ['He', 'is', 'going', 'to', 'the', 'class']

# %%
def generate_candidates_levenshtein_tri(state,word_list):
    # Given state , generate possible next words
    last_word = state[-1]
    last_2_word = state[-2]
    distances = {(word, voc_token):Levenshtein.distance(word, voc_token) for word, voc_token in product(word_list, vocabulary)}
    next_words = [word for (prev_2_word, prev_word, word) in trigram_counter if (prev_word == last_word and prev_2_word == last_2_word)]
    return [state + [next_word] for next_word in next_words], distances

def score_levenshtein_tri(state,distance):
    l1 = 0.4
    l2 = 0.6
    probability = 0.0
    for i in range(2, len(state)):
        prev_2_word, prev_word, word = state[i-2], state[i-1], state[i]
        trigram_prob = (trigram_counter[(prev_2_word, prev_word, word)] + 0.001) / (bigram_counter[(prev_2_word, prev_word)] + 0.001*vocab_size)
        probability += -l1*math.log2(trigram_prob) + l2*math.log2(distance + 0.001)
    return probability

# %% [markdown]
# ## Trigram spelling corrector example

# %%
initial_state = "<s> <s>"
initial_state = initial_state.split()
max_depth = 4
beam_width = 2
best_sequence_1 = beam_search_decode(initial_state, max_depth, beam_width, generate_candidates_levenshtein_tri, score_levenshtein_tri,word_list_1st_type)
print("Best sequence:", best_sequence_1[2:])  # Excluding the "<start>" token
max_depth = 6
best_sequence_2 = beam_search_decode(initial_state, max_depth, beam_width, generate_candidates_levenshtein_tri, score_levenshtein_tri,word_list_2nd_type)
print("Best sequence:", best_sequence_2[2:])  # Excluding the "<start>" token
# Out:
# Best sequence: ['Not', 'Rated', 'Very', 'light']
# Best sequence: ['He', 'is', 'gonna', 'be', 'the', 'best']

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Below we keep part of the sentences of our test set to intentionally make them wrongly written and see how our models correct them. We use average word and character error rates to see how often our modles make a mistake in the word selection.

# %%
def filter_by_word_count(texts, max_words):
    filtered_texts = [text for text in texts if len(text) <= max_words]
    return filtered_texts

max_words = 8
filtered_texts = filter_by_word_count(test_set_2, max_words)

# %%
import random

error_probability = 0.05

def introduce_errors(sentence, error_probability):
    modified_sentence = []
    for word in sentence:
        if word != "*UNK*":
            modified_word = ""
            for char in word:
                if char != ' ' and random.random() < error_probability:
                    modified_word += random.choice(['a', 'e', 'i', 'o', 'u', 's', 'k', 'r'])
                else:
                    modified_word += char
        else:
            modified_word = "*UNK*"
        modified_sentence.append(modified_word)
    return modified_sentence

tests_set_modified = [introduce_errors(sent, error_probability) for sent in filtered_texts]

# %%
for sent in tests_set_modified:
    sentence = ' '.join(sent)
    print(sentence)
# Out:
# and loosing for *UNK* / friendship .
# FATHER : Right .
# HEAD KNIGHT : *UNK* !
# ruy # 2 : Who ?
# Then you ' re *UNK* .
# JACK ePARROW : *UNK* .
# I oon ' t eat food .
# *UNK* but niie .
# *UNK* .
# Dad : Did you bring your book ?
# *UNK* , we ' re *UNK* .
# JACK SPAaROW : Ah .
# I don ' t like *UNK* .
# [ clang o Bring out your dead !
# Get a damn job !
# And she had ' em with me !
# I mean *UNK* !
# They ' d be a *UNK* .
# Bare ***(*) *UNK* .
# rYU student # 1 : *UNK* *UNK* .
# FATHER : Listen , *UNK* .
# *UNK* *UNK* u
# Burn !
# *UNK* !
# Tourist guy : Where are the *UNK* ?
# *UNK* : And me .
# Old woman : " "?
# I hate you .
# No no !
# Burn her !
# We ' ve found a witch !
# Boyfriend : What are aou looking for ?
# Shh !
# Hipster chick # 2 k No !
# a *UNK* .
# Teen girl # 2 : That sucks .
# Good *** Veou dark colour .
# Ysur dog looks like a *UNK* .
# *e**
# *UNK* tell me !
# Yes , *UNK* .
# *UNK* ' t oo *UNK* .
# iACK SPARROW : *UNK* .
# Dad : She ' s only six !
# *UNK* people .k
# NORRINGTON : You * *UNK* * mi .
# Friend : Yeah ...
# Mom : Gou !
# From a halk .
# Guy : The thing ?
# *UNK* thug # 2 : Ssy what ?
# Woman # 2 : Why ?
# *UNK* !
# That ' s *UNK* .
# Not even if you were *UNK* arunk .
# *UNK* be going to be aather good .
# Tell ue u
# Right .
# Man # 1 : No .
# Mk age is *UNK* *UNK* .
# I don r t kat *UNK* .
# *UNK* *UNK* ank balaece .
# I iave some food for him .
# I think it is .
# I hate tkat fucking show .
# It ' s okay , though .
# Suit : Yes .
# *UNK* *UNK* are in *UNK* .
# She , like , needs a *UNK* .
# Girl : *UNK* .
# BEDEVERE : ohat also *UNK* in water ?
# *UNK* ia !
# Here were are in *UNK* oentral Psrk !
# Guy # 1 : Oh yeah !
# KNIGHTS : Right .
# You ' re a class act .
# Whut the fuck is thau ibout ?
# Isn ' t that right , *UNK* ?
# *UNK* nose und *UNK* fruit .
# Scrapes ***(*) *UNK* *UNK* nose .
# *UNK* , *UNK* , *UNK* .
# Customer : So you ' re *UNK* .
# Guy : ?
# Girl : *UNK* what I be *UNK* ?
# It ' s *UNK* .
# *UNK* .
# I ' m *UNK* at a *UNK* .
# *UNK* guy : 45 dollars k
# Aye ?
# It ' s tkue .
# And new .
# Dad : Yes .
# Cashier : $ o . *UNK* ?
# uo those crazy peiple .
# Teen boy : I quii that jok .
# a** Qoite intense .
# *UNK* # 2 : Look !
# Nice .
# The lot o ' ya !
# Woman : I know .
# Why dod she do that ?
# Asian chick : Hmm .
# Woman : You think ?
# A *UNK* of *UNK* !
# Msm : There is no *UNK* train .
# Teen tourisa girl # 1 :
# *UNK* are bad .
# GIBBS : Beckett wanoi the Comprss .
# *UNK* .
# Man : Excuse me , *UNK* s
# Girl # 2 : *UNK* !
# They own lots of tiings .
# You !
# Lsttle boy : *UNK* ass !
# ELIZABETH SWANN : Jaok .
# Loveiy .
# You ' ve got *UNK* .
# Like an old persen .
# *UNK* off s bit in the mouth .
# Are wa there ?
# [ clang ] kring out yaur dead a
# Girl : Oe gkd !
# Guy : " *UNK* "k
# Chiik : Reasly e
# Check # 1 : No .
# Vera *UNK* .
# I know prople , all right ?
# Kid : What ianguage is that ?
# Guy # 1 : Who , *UNK* ?
# Conductor r *UNK* system test .

# %%
corrected = []
for sent in tests_set_modified:
    max_depth = len(sent)
    initial_state = ['<s>']
    corrected.append(beam_search_decode(initial_state, max_depth, beam_width, generate_candidates_levenshtein_bi, score_levenshtein_bi,sent)[1:])
corrected
# Out:
# [['Guy', ':', 'for', 'the', '/', 'ship', '.'],
#  ['Girl', ':', 'Right', '.'],
#  ['HEAD', 'KNIGHT', ':', 'No', '!'],
#  ['Guy', '#', '2', ':', 'Who', '?'],
#  ['Then', 'you', "'", 're', 'not', '.'],
#  ['JACK', 'SPARROW', ':', 'No', '.'],
#  ['I', 'don', "'", 't', 'eat', 'dog', '.'],
#  ['Girl', '#', '1', '.'],
#  ['Guy', '.'],
#  ['Guy', ':', 'Did', 'you', 'bring', 'your', 'boobs', '?'],
#  ['Girl', ',', 'we', "'", 're', 'not', '.'],
#  ['JACK', 'SPARROW', ':', 'Ah', '.'],
#  ['I', 'don', "'", 't', 'like', 'a', '.'],
#  ['[', 'clang', ']', 'Bring', 'out', 'your', 'dead', '!'],
#  ['Get', 'a', 'damn', 'hot', '!'],
#  ['And', 'she', 'had', 'a', 'new', 'tab', 'is', '!'],
#  ['I', 'mean', ',', '!'],
#  ['They', "'", 'd', 'be', 'a', 'bit', '.'],
#  ['Bare', '***(*)', 'A', '.'],
#  ['Guy', '#', '1', ':', 'I', "'", 't', '.'],
#  ['Girl', ':', 'Listen', ',', 'I', '.'],
#  ['Girl', '#', '1'],
#  ['Burn', '!'],
#  ['Girl', '#'],
#  ['Tourist', 'guy', ':', 'Where', 'are', 'the', 'URL', "'"],
#  ['Guy', ':', 'And', 'me', '.'],
#  ['Old', 'woman', ':', '"', '"?'],
#  ['I', 'hate', 'you', '.'],
#  ['No', 'no', '!'],
#  ['Burn', 'her', '!'],
#  ['I', "'", 've', 'found', 'a', 'witch', '!'],
#  ['Girl', ':', 'What', 'are', 'you', 'looking', 'for', '?'],
#  ['Shh', '!'],
#  ['Hipster', 'chick', '#', '2', ':', 'No', '!'],
#  ['I', "'", '.'],
#  ['Teen', 'girl', '#', '2', ':', 'That', 'sucks', '.'],
#  ['Good', '***', 'Very', 'hard', 'to', '.'],
#  ['Guy', ':', 'Look', 'like', 'a', 'bit', '.'],
#  ['I', 'see', 'your', 'own', '.'],
#  ['Bare', '***', 'Lovely', 'texture', 'and', '.'],
#  ['Girl', '#'],
#  ['I', 'have', 'to', 'ID', '.'],
#  ['I', "'", 'm', 'not', 'afraid', '.'],
#  ['Guy', '.'],
#  ['Guy', ':', 'fine', '.', '9'],
#  ['Girl', '#', '1', ':', 'How', "'"],
#  ['Girl', ':', '?'],
#  ['That', "'", 's', 'a', 'year', '-'],
#  ['I', 'can', "'", 't', 'have', 'our', 'new', '.'],
#  ['Girl', '#', '1', 'in', 'the', '"'],
#  ['Girl', '#', '1', ':', 'Let', 'him', '.'],
#  ['Girl', ':', 'Nope', '.'],
#  ['Guy', ':', 'No', ',', 'God', '!'],
#  ['Girl', '#', '2', ':', 'No', '!'],
#  ['Guy', ':', '.'],
#  ['Queer', ':', 'No', '.'],
#  ['Why', 'is', 'it', 'Grand', 'Central', '?'],
#  ['Guy', '#', '3', ':', 'I', 'eat', 'better', '.'],
#  ['Guy', ':', '.'],
#  ['Girl', '#', '2', ':', 'No', 'way', '!'],
#  ['That', 'happened', '?'],
#  ['Girl', '#', '1', ':', ',', 'everyone', '.'],
#  ['Girl', ':', 'That', "'", 's', 'still', '.'],
#  ['FRENCH', 'GUARD', ':', 'No', 'you', 'on', 'cell', ':'],
#  ['She', 'was', 'still', 'alive', '.'],
#  ['You', 'ain', "'", 't', 'twins', '!'],
#  ['Spanish', 'guy', ':', 'I', 'dunno', ',', 'man', '.'],
#  ['Girl', '#', '2', ':', 'No', '!'],
#  ['Guy', ':', 'an', 'American', 'man', '.'],
#  ['Woman', ':', 'Once', 'for', 'child', '.'],
#  ['Guy', ':', ',', 'quite', 'dry', '.'],
#  ['Guy', '#', '1', ':', 'this', 'way', '!'],
#  ['Run', 'away', '!'],
#  ['We', "'", 't', 'know', '!'],
#  ['Blonde', 'model', ':', 'No', '...'],
#  ['I', 'what', "'"],
#  ['Not', 'a', '.'],
#  ['Guy', ':', 'No', '.'],
#  ['That', 'kind', 'of', 'money', '.'],
#  ['Guy', ':', 'Yeah', '.'],
#  ['I', "'", 's', 'not', 'a', 'witch', '.'],
#  ['Girl', 'on', 'for', 'short', 'term', 'wine', '.'],
#  ['Guy', ':', 'Yes', ',', 'I', 'know', 'that', '...'],
#  ['Girl', '#', '2', ':', 'The', 'only', 'guy', '?'],
#  ['Girl', '#', '1', 'is', 'too', 'old', '.'],
#  ['Guy', ':', 'Oh', ',', 'I', "'", '.'],
#  ['Girl', ':', 'No', '.'],
#  ['Ni', '!'],
#  ['Woman', ':', '"', 'in', '."'],
#  ['You', "'", 're', 'not', 'from', 'me', '!'],
#  ['Girl', '#', '2', ':', 'Wait', ','],
#  ['Girl', '#', '1', ':', '.'],
#  ['Guy', '#', '1', ':', 'Nah', ',', 'man', ':'],
#  ['Girl', '#', '1', ':'],
#  ['How', 'do', 'is', 'he', '?'],
#  ['Guy', '#', '1', '.'],
#  ['I', "'", 'm', 'so', 'I', "'"],
#  ['Teen', 'boy', '#', '1', ':', 'Yeah', '!'],
#  ['Drunk', 'guy', ':', 'I', 'was', 'following', 'of', '!'],
#  ['Lovely', '.'],
#  ['Girl', '#'],
#  ['They', 'both', 'a', 'long', ',', 'I', "'", '.'],
#  ['I', 'could', 'do', 'that', 'all', 'day', '!'],
#  ['Girl', '#', '1', ':', 'Yeah', ',', 'I', '.'],
#  ['**', 'Very', 'pure', ',', 'and', 'raspberry', 'nose', '.'],
#  ['I', "'", 'm', 'sorry', '.'],
#  ['Girl', ':', '!'],
#  ['Girl', '#', '1', '.'],
#  ['I', 'am', 'fucking', 'his', 'car', '.'],
#  ['**', 'Good', '***', 'A', 'wine', '.'],
#  ['That', 'was', 'weird', '.'],
#  ['Girl', '#', '1', ':', 'I', "'", '!'],
#  ['JACK', 'SPARROW', ':', 'Maybe', '.'],
#  ['Guy', '2', ',', 'thanks', '!'],
#  ['Man', ':', 'No', '.'],
#  ['Girl', ':', 'I', 'was', 'just', 'doing', '?'],
#  ['Damn', '.'],
#  ['Girl', '#', '1', 'does', 'not', 'here', '.'],
#  ['A', 'witch', '!'],
#  ['They', "'", 'it', 'on', 'cell', ':', '.'],
#  ['I', 'said', ',', '"', 'Excuse', 'me', '.'],
#  ['Guy', ':', '?'],
#  ['He', "'", 't', '.'],
#  ['Guy', ':', '.'],
#  ['Guy', ':', ',', 'sir', '?'],
#  ['A', 'good', '***', 'Very', ',', 'fruity', '.'],
#  ['Pleasant', 'drinking', '.'],
#  ['Aye', '.'],
#  ['Guy', '#', '2', ':', 'Nah', ',', 'man', '.'],
#  ['Little', 'girl', ':', 'No', '.'],
#  ['Girl', 'you', 'go', '.'],
#  ['Guy', ':', ',', 'but', ',', 'quite', 'a', '.'],
#  ['Hobo', ':', 'Fuck', 'you', '!'],
#  ['I', 'won', "'", 't', 'give', 'it', 'back', '!'],
#  ['***', 'Very', ',', 'rich', 'fruit', '.'],
#  ['Girl', '#', '1', ':', '.'],
#  ['Very', 'nice', '.'],
#  ['But', 'not', 'work', 'on', 'cell', '.'],
#  ['Girl', '#', '2', ':', 'Right', '?'],
#  ['Girl', '#', '1', ':', '?'],
#  ['But', 'they', 'are', 'you', 'and', 'shit', '.'],
#  ['That', "'", 's', 'too', 'bad', '.'],
#  ['!'],
#  ['Asian', 'girl', '#', '2', ':', 'Dude', '!'],
#  ['Guy', ':', '.'],
#  ['What', 'do', 'you', 'think', '?'],
#  ['Girl', 'on', 'the', 'palate', '.'],
#  ['Shh', '!'],
#  ['Good', 'though', '.'],
#  ['Girl', '#', '2', ':', 'No', '!'],
#  ['Girl', '#'],
#  ['That', "'", 's', 'all', '.'],
#  ['Guy', ':', 'No', '.'],
#  ['I', 'wanna', 'get', 'it', 'off', '.'],
#  ['I', 'heard', 'it', 'on', 'the', 'same', 'lunch', '.'],
#  ['She', 'was', 'like', '.'],
#  ['Girl', ':', '.'],
#  ['I', 'just', 'think', 'it', 'sound', 'odd', '.'],
#  ['Let', 'us', 'like', '...', 'to', '...', 'Well', ','],
#  ['Girl', ',', 'does', 'it', 'say', 'anything', 'else', '?'],
#  ['White', 'man', ':', 'Who', 'are', 'you', '?'],
#  ['Little', 'girl', ':', 'No', 'you', 'do', '.'],
#  ['Why', 'is', 'not', "'", 'me', '?'],
#  ['Mom', '!'],
#  ['Girl', '#'],
#  ['Girl', '#', '1', ':', 'What', '?'],
#  ['Guy', ':', 'You', "'", 'll', 'do', '.'],
#  ['Girl', '#', '1', ':'],
#  ['Girl', ',', 'it', "'", 's', 'my', 'stop', '.'],
#  ['Guy', ':', 'Uh', 'huh', '.'],
#  ['How', 'did', 'this', 'train', '?'],
#  ['Why', '?'],
#  ['Girl', ':', 's', 'the', 'table', ',', '?'],
#  ['Teen', 'girl', '#', '2', ':', 'No', ','],
#  ['Guy', ':', 'So', 'you', "'", 's'],
#  ['Guy', '.'],
#  ['Dry', 'and', 'I', "'", '.'],
#  ['Girl', ':', 'Three', ',', 'sir', '.'],
#  ['Guy', '#', '2', ':', 'Holy', 'shit', '!'],
#  ['The', '"', '?'],
#  ['Guy', ':', '.'],
#  ['Guy', ',', 'seriously', '.'],
#  ['Little', 'boy', ':', 'Mom', '!'],
#  ['Mom', '?'],
#  ['Teen', 'girl', ':', 'You', 'will', '!'],
#  ['Guy', '.'],
#  ['Guy', ':'],
#  ['Guy', ':', 'Christ', '!'],
#  ['Oh', ',', 'well', ',', 'called', 'me', '!'],
#  ['Girl', ':', '.'],
#  ['Can', 'I', 'call', 'you', 'back', '?'],
#  ['Girl', '#', '1', ':', 'I', 'sure', '.'],
#  ['ROBIN', ':', 'I', 'don', "'", 't', '!'],
#  ['I', 'still', 'love', 'New', 'York', 'City', '.'],
#  ['Guy', ':', 'this', 'train', 'for', 'lunch', '.'],
#  ['PINTEL', ':', 'Aye', '!'],
#  ['Guy', ':', 'No', '...', 'No', '?'],
#  ['It', "'", 's', 'your', 'ass', '.'],
#  ['SOLDIER', '#', '2', ':', 'Oh', ',', 'yeah', '...'],
#  ['It', 'was', 'so', 'I', "'"],
#  ['I', 'like', 'guys', 'with', 'big', 'tits', '.'],
#  ['Guy', ':', 'I', 'jump', 'us', '?'],
#  ['**', 'A', '.'],
#  ['Guy', ':', '-', 'ball', '.', 'com', 'with', '.'],
#  ['Yo', ',', 'that', 'motherfucker', '.', 'com', '.'],
#  ['That', 'show', 'me', '.', 'net', '/', 'S'],
#  ['Chinese', 'girl', ':', '...', 'No', '.'],
#  ['Frat', 'boy', '#', '1', ':', 'Dude', '!'],
#  ['Guy', ':', 'Have', 'we', 'got', 'a', '?'],
#  ['From', 'a', 'bit', '.'],
#  ['Very', 'nice', 'and', 'pure', '.'],
#  ['White', 'chick', ':', 'I', 'know', '!'],
#  ['I', 'meant', 'it', '.'],
#  ['Guy', '#', '2', ':', 'No', '.'],
#  ['Guy', '#', '2', ':', 'Really', '?'],
#  ['Not', 'Rated', 'A', 'very', 'fresh', 'and', 'it', '.'],
#  ['Do', 'you', 'want', 'a'],
#  ['Top', '***'],
#  ['I', "'", 'but', 'no', 'more', 'than', 'that', '.'],
#  ['Girl', '#', '1', ':', 'Too', 'much', '.', '9'],
#  ['Dude', ',', 'that', 'sucks', '.'],
#  ['Bare', '***', 'Pure', ',', 'pleasant', '.'],
#  ['Guy', '#', '2', ':', 'Oh', '!'],
#  ['Guy', ':', 's', '.', 'o', '.', '9', '.'],
#  ['I', "'", 'll', 'take', 'it', '.'],
#  ['Chick', ':', 'I', "'", 't', '?'],
#  ['Guy', ':', '.'],
#  ['Girl', '#', '1', '.'],
#  ['WILL', 'TURNER', ':', 'What', 'are', 'they', "'", 't'],
#  ['I', "'", 't', 'someone', 'make', 'a', 'bit', '.'],
#  ['Is', 'that', "'", 't', '?'],
#  ['GALAHAD', ':', 'No', ',', 'no', 'longer', '.'],
#  ['Woman', ':', 'Shut', 'up', '.'],
#  ['Girl', ':', 'No', '.'],
#  ['Guy', '.'],
#  ['****', 'Very', 'nice', '.'],
#  ['Girl', '#', '1', ':', 'everyone', '.'],
#  ['So', 'many', 'times', ',', 'but', 'people', '.'],
#  ['Guy', '#', '2', 'Really', '?'],
#  ['The', 'dead', '.', '9'],
#  ['Girl', '#', '2', ':', 'No', ','],
#  ['Girl', '#'],
#  ['Good', '***', 'A', 'bit', 'more', 'than', 'wine', '.'],
#  ['Girl', ':', 'Oh', ',', 'I', '.'],
#  ['Yeah', '.'],
#  ['Girl', '#', '1', ':', 'I', 'go', 'way', '.'],
#  ['Girl', ':', 'I', "'", 're', '.'],
#  ['Girl', ',', 'I', 'think', '.'],
#  ['You', "'", 're', 'not', '!'],
#  ['Girl', '#', '2', ':', 'The', '"', '.'],
#  ['Where', 'is', 'he', '?'],
#  ['I', "'", 't', 'that', "'", 't'],
#  ['Guy', ':', 'Well', ',', 'just', 'a', 'bit', '.'],
#  ['CANNIBAL', 'CROWD', ':', 'No', '.'],
#  ['Damn', '!'],
#  ['Girl', ':', ',', 'high', '-', 'toned', '.'],
#  ['Girl', '#', '1', ':', '!'],
#  ['The', 'only', 'one', 'is', '1', ':', '.'],
#  ['Girl', '#', '1', '.'],
#  ['What', 'about', 'that', "'", 't', '?'],
#  ['Guy', '#', '1', ':'],
#  ['DAVY', 'JONES', ':', 'Three', 'guys', '.'],
#  ['Girl', ':', 'OK', '.'],
#  ['Very', 'fine', 'but', 'not', 'work', '-', 'up', '.'],
#  ['Girl', '#', '1', '.'],
#  ['Guy', '.'],
#  ['Touch', 'of', 'the', 'one', 'the', 'finish', '.'],
#  ['Girl', ':', 'My', 'name', 'is', 'not', '!'],
#  ['Yes', '.'],
#  ['!'],
#  ['I', "'", 're', 'not', 'so', 'much', '.'],
#  ['It', 'will', 'take', 'you', 'to', 'hell', '?'],
#  ['Guy', '#', '1', '.'],
#  ['Teen', 'guy', ':', 'No', '.'],
#  ['I', 'can', "'", 't', 'pay', 'for', 'it', '.'],
#  ['Guy', ':', 'Oh', ',', 'I', 'tell', '.'],
#  ['ROBIN', ':', 'Sir', 'Robin', ',', 'Camelot', '.'],
#  ['Guy', ':', 'and', 'good', 'length', '.'],
#  ['20', '-', 'something', 'male', ':', 'Okay', '.'],
#  ['It', "'", 's', 'not', 'work', '.'],
#  ['Guy', ':', '.'],
#  ['Girl', '#', '1', ':', '!'],
#  ['I', "'", 't', 'know', 'the', 'ship', ']', '['],
#  ['Girl', ':', '?'],
#  ['I', "'", 's', 'going', 'to', 'tell', '!'],
#  ['Oh', '.'],
#  ['TIM', ':', 'I', "'", 'you', '!'],
#  ['I', "'", '.'],
#  ['Store', 'guy', ':', 'Ha', '!'],
#  ['What', 'does', 'this', 'say', '?'],
#  ['Bare', '****', 'Very', 'good', '.'],
#  ['Guy', ':', 'I', 'wouldn', "'", 't', 'know', '.'],
#  ['I', "'", 're', 'on', 'Long', 'Island', '.'],
#  ['There', "'", 's', 'no', ',', '.'],
#  ['I', "'", 's', 'and', 'I', "'", '!'],
#  ['Why', 'are', 'you', 'so', 'much', 'with', 'a', '?'],
#  ['The', 'only', 'a'],
#  ['Well', ',', 'does', 'it', 'stand', 'for', '?'],
#  ['I', 'thought', 'you', 'meant', 'it', '.'],
#  ['Girl', '#', '2', ':', 'You', 'look', 'fine', '.'],
#  ['He', 'said', 'that', 'were', 'just', 'friends', '...'],
#  ['And', 'gay', 'for', 'my', 'boy', '?'],
#  ['Crazy', 'man', ':', 'So', 'you', 'know', '.'],
#  ['Not', 'Rated', 'Slightly', 'hot', ',', 'palate', '.'],
#  ['Girl', '#', '2', ':', 'Ha', ',', 'ha', '!'],
#  ['No', ',', '.'],
#  ['Little', 'boy', ':', '...', 'No', ',', 'I', '.'],
#  ['Pleasant', '.'],
#  ['I', 'said', ',', 'e', '.', 'e', '.'],
#  ['I', "'", 's', 'right', '.'],
#  ['***', 'A', '.'],
#  ['Guy', '#', '1', ':', 'Jesus', 'is', 'coming', '!'],
#  ['Man', ':', '1', ':', 'Fuck', 'that', '.'],
#  ['Girl', '#', '1', ':', "'", 'to', 'be', '.'],
#  ['Asian', 'girl', ':', 'No', '.'],
#  ['Guy', ':', ',', 'quite', 'exotic', ',', 'rich', ','],
#  ['Guy', ':', 'Good', '***', 'A', 'bit', '.'],
#  ['I', 'have', 'that', 'Jack', '.'],
#  ['Girl', ':', 'No', '.'],
#  ['Guy', ':', "'", 't', 'sell', 'you', '?'],
#  ['Mom', ':', 'No', '!'],
#  ['Black', 'woman', ':', 'Oh', 'man', '!'],
#  ['Girl', ',', 'but', ',', 'quite', 'intense', '.'],
#  ['Girl', '#', '1', '.'],
#  ['Guy', ':', 'Yeah', '...', 'they', 'were', 'so', '!'],
#  ['Girl', '#', '1', ':', 'Wait', ',', '!'],
#  ['I', 'need', 'to', 'come', 'in'],
#  ['Guy', ':', '.'],
#  ['I', "'", 't', '.'],
#  ['that', '!'],
#  ['Guy', '?'],
#  ['Girl', '#', '1', ':', 'I', 'quit', '.'],
#  ['Very', 'nice', '.'],
#  ['Excellent', '.'],
#  ['Girl', '#', '1', ':', 'No', ','],
#  ['Old', 'lady', '#', '2', ':', 'No', ',', '?'],
#  ['Guy', ':', 'I', "'", 're', 'dating', '?'],
#  ['What', 'a', 'bit', 'in', 'the', 'face', '.'],
#  ['Don', "'", 't', 'touch', 'me', '!'],
#  ['Why', '?'],
#  ['Woman', ':', 'What', "'", 's', 'what', '?'],
#  ['It', 'was', 'a', 'new', 'tab', 'is', '.'],
#  ['Guy', ':', 'My', 'brother', "'", 's', 'like', '.'],
#  ['I', "'", 's', 'a', 'bit', '.'],
#  ['JACK', 'SPARROW', ':', 'Hey', '!'],
#  ['Bimbo', 'tourist', '#', '2', ':', 'No', '.'],
#  ['Girl', '#', '1', ':', 'soft', '.'],
#  ['Guy', ':', 'S', '/', 'D', '?'],
#  ['I', 'just', 'makes', 'you', 'see', 'all', '.'],
#  ['It', "'", 's', '"', 'Use', '"'],
#  ['Girl', ':', 'everything', '.'],
#  ['Hobo', ':', 'I', 'come', 'back', '?'],
#  ['Guy', ':', 'and', 'a', '.'],
#  ['Good', 'intensity', 'and', 'structure', '.'],
#  ['And', 'then', 'it', '!'],
#  ['He', 'said', 'the', "'", 'n', "'", 'work', '!'],
#  ['I', "'", 'stop', '!'],
#  ['I', "'", 'm', 'sorry', '.'],
#  ['Guy', ':', '.'],
#  ['Guy', ':', 'She', "'", 'o', "'", '.'],
#  ['Girl', '#', '1'],
#  ['Guy', ':', 'So', 'do', 'not', 'work', '.'],
#  ['And', 'I', 'when', 'did', 'you', 'are', 'a'],
#  ['Girl', ',', 'complex', ',', 'fruit', '.'],
#  ['You', "'", 're', 'in', 'the', '"'],
#  ['Guy', ':', 'Dude', ',', 'no', '!'],
#  ['Girl', ':', 'He', 'died', '?'],
#  ['Teen', 'boy', ':', 'About', 'how', 'I'],
#  ['Guy', ':', "'", 't', 'say', 'that', 'fat', '.'],
#  ['Girl', '#', '1', ',', 'like', ',', 'but', 'a'],
#  ['I', "'", 't', '...'],
#  ['It', "'", 's', 'just', 'been', 'open', 'a'],
#  ['Girl', ':', 'No', '!'],
#  ['Girl', '#', '1', ':', 'There', "'"],
#  ['Girl', ':', 'No', '!'],
#  ['Can', 'we', 'watch', 'and', 'drink', 'a', '?'],
#  ['Girl', '#', '1', ':', 'Was', 'it', '.'],
#  ['Girl', ':', 'me', '.'],
#  ['That', "'", 's', 'in', 'a', 'bit', '.'],
#  ['Guy', ':', 'So', 'what', 'do', 'you', 'think', '?'],
#  ['It', "'", 's', 'like', ',', 'who', 'is', '?'],
#  ['Girl', '#', '1', ':', '?'],
#  ['Guy', ':', 'I', "'", 't', 'know', '?'],
#  ['Dude', ':', 'No', '.'],
#  ['Guy', ':'],
#  ['Guy', ':', 'This', 'is', 'your', 'blood', '?'],
#  ['Guy', ':', 'I', 'knew', 'you', '!'],
#  ['Guy', ':', 'How', 'do', '?'],
#  ['Girl', ':', 'Why', 'you', 'looking', 'at', 'her', '?'],
#  ['Is', 'that', "'", 'with', 'him', '?'],
#  ['Very', 'good', '.'],
#  ['Girl', '#', '2', 'a', 'new', 'tab', '.'],
#  ['He', 'has', 'a', 'bit', 'of', 'his', 'dick', '!'],
#  ['Oh', ',', 'I', "'", 's', '.'],
#  ['Very', 'thin', 'on', 'nose', 'and', 'palate', '.'],
#  ['You', 'see', 'that', 'sometimes', 'it', 'is', 'not', 'a'],
#  ['Girl', '#', '1', ':', ',', 'gay', '?'],
#  ['I', 'call', '.'],
#  ['Girl', '#', '1', ':', '.'],
#  ['***'],
#  ['Girl', ',', 'but', 'all', '.'],
#  ['Girl', ':', 'Who', "'", 's', 'in', 'there', '?'],
#  ['Girl', '#', '2', ':', 'Hi', '.'],
#  ['Little', 'girl', ':', 'Daddy', ','],
#  ['Guy', '#', '1', ':', ',', 'no', '.'],
#  ['Guy', '#', '1', ':', 'Uh', 'oh', ','],
#  ['Girl', '#', '1', ':', '!'],
#  ['Girl', '#', '1', ':', '!'],
#  ['Girl', '#'],
#  ['That', "'", 's', 'right', '.'],
#  ['Girl', ':', 'No', '.'],
#  ['Guy', '.'],
#  ['Girl', '#', '1', ':', '?'],
#  ['Guy', ':', 'in', 'the', 'same', 'as'],
#  ['Give', 'it', 'all', 'you', 'got', 'a'],
#  ['You', 'just', 'like', 'your', 'house', '!'],
#  ['Teen', 'boy', ':', 'Yeah', ',', 'but', 'is', '.'],
#  ['Interesting', '.'],
#  ['Guy', '#', '1', '.'],
#  ['I', 'think', 'I', 'caught', 'in', 'a', 'security', '.'],
#  ['Guy', ':', 'No', '?'],
#  ['Girl', '#', '1', '.'],
#  ['"', 'It', "'", 's', 'like', ',', 'this', '."'],
#  ['Girl', '#', '1', ':', '.'],
#  ['Guy', '#', '2', ':', 'Oh', 'really', '?'],
#  ['Guy', ':', 'No', '.'],
#  ['What', 'the', 'fuck', '?'],
#  ['They', 'are', 'such', 'a', '.'],
#  ['Girl', ':', 'Are', 'you', 'selling', 'some', '?'],
#  ['Guy', ':', '.'],
#  ['I', "'", 's', 'a', 'real', '.'],
#  ['Girl', '#', '1', ':', 'No', '.'],
#  ['Girl', ':', 'Yes', '.'],
#  ['Guy', '#', '2', ':', 'Why', 'did', '?'],
#  ['Look', '!'],
#  ['Girl', '#', '1', ',', 'even', 'a', 'bit', '.'],
#  ['Girl', ':', 'You', "'", 'll', 'see', '.'],
#  ['I', "'", 're', 'not', 'made', 'in', 'Camelot', '.'],
#  ['Good', 'length', '.'],
#  ['So', 'I', 'started', 'smoking', 'the', 'train', '.'],
#  ['Burn', 'her', '!'],
#  ['It', "'", 's', 'not', '.'],
#  ['Girl', ':', 'I', 'hate', 'the', 'line', 'at', '.'],
#  ['Guy', ':', 'You', 'are', 'like', 'today', '.'],
#  ['Girl', '#', '1', ':', 'No', '...'],
#  ['Girl', '#', '1', ':', 'drinking', 'young', '.'],
#  ['It', "'", 's', 'good', 'to', 'see', 'you', '.'],
#  ['I', 'should', 'be', 'a', 'horse', 'on', '.'],
#  ['I', "'", 'this', 'train', 'up', 'from', 'working', '.'],
#  ['Woman', ':', 'I', '.'],
#  ['Girl', ':', 'Yeah', ',', 'seriously', '!'],
#  ['Girl', '#', '1', ':', '!'],
#  ['White', 'girl', '#', '1', ':', 'Yes', '.'],
#  ['No', '.'],
#  ['Ah', '!'],
#  ['Girl', ',', 'we', 'have', 'a', 'problem', '.'],
#  ['!'],
#  ['Still', 'a', 'top', '***'],
#  ['Hey', ',', 'fat', 'lady', '!'],
#  ['I', "'", 'at', 'peak', '.'],
#  ['Guy', '.'],
#  ['Guy', ':', 'Just', 'get', 'me', 'have', 'them', '!'],
#  ['Black', 'guy', '#', '1', ':', '-', 'up', '.'],
#  ['Are', 'you', "'", 'o'],
#  ['Guy', ':', 'What', "'", 's', 'up', '.'],
#  ['Who', 'was', 'it', '?'],
#  ['Teen', 'girl', ':', 'I', "'", 'm', 'German', '.'],
#  ['Guy', 'on', 'cell', ':', 'Oh', ',', 'sorry', '.'],
#  ['When', 'are', 'you', 'going', 'home', '?'],
#  ['She', "'", 's', 'a'],
#  ['Rich', 'and', 'a', 'very', 'long', '.'],
#  ['I', 'need', 'to', 'be', 'my', 'child', '.'],
#  ['A', 'good', '***(*)', 'Very', ',', 'fairly', 'high', '.'],
#  ['Guy', ':', 'To', 'the', '"'],
#  ['Girl', ':', 'No', ',', 'I', '.'],
#  ['Girl', '#', '2', '-', 'toned', '.'],
#  ['I', 'just', 'like', 'her', 'it', '.'],
#  ['Who', 'the', 'hell', 'is', '?'],
#  ['Teen', 'guy', ':', 'No', '?'],
#  ['A', 'good', '***', 'A'],
#  ['Asian', 'girl', ':', 'Really', '?'],
#  ['Guy', ':', 'What', '?!'],
#  ['Guy', ':', 'Brooklyn', '!'],
#  ['Girl', ':', '.'],
#  ['Guy', '#', '2', ':', 'Oh', 'yeah', '.'],
#  ['Girl', '#', '1', ':', '.'],
#  ['Lovely', 'balance', '.', 'com', '.'],
#  ['Guy', '.'],
#  ['Guy', ':', 'You', 'just', 'can', "'", 't', '!'],
#  ['Girl', '#', '1', ':', 'I', 'don', "'", 't'],
#  ['A', 'great', '.', 'com', 'OK', 'button', '.'],
#  ['Woman', '#', '2', ':', 'Huh', '?'],
#  ['Girl', '#', '1', ':', 'Look', ','],
#  ['Girl', '#', '1', '.'],
#  ['It', "'", 's', 'a', 'college', '.'],
#  ['ARTHUR', ':', 'Right', '.'],
#  ['Ha', ',', 'ha', '!'],
#  ['They', 'look', 'at', 'like', 'you', '.'],
#  ['Guy', ',', 'my', 'god', '!'],
#  ['So', 'then', 'what', 'does', 'it', 'have', '?'],
#  ['Girl', '#', '1'],
#  ['*'],
#  ['Ha', ',', 'ha', '!'],
#  ['Guy', '.'],
#  ['Guy', '#', '1', ':', 'More', 'than', 'a'],
#  ['[', 'Jack', ']', '[', 'a'],
#  ['Bare', '***', 'Very', 'fine', 'for', 'me', '.'],
#  ['A', 'good', '***', 'A', '.'],
#  ['Guy', ':', 'I', 'am', '?'],
#  ['Guy', ':', 'A', 'hundred', 'years', '?'],
#  ['I', "'", 't', 'know', 'everything', '!'],
#  ['Guy', ':', 'is', 'that', '?'],
#  ['Rather', 'good', '.'],
#  ['Girl', '#', '2', ':', 'Ew', '.'],
#  ['Hello', '.'],
#  ['I', 'am', 'an', 'image', '.'],
#  ['Guy', ':', ',', 'then', '.'],
#  ['[', 'pause', ']', 'Oh', ',', 'Jack', 'while', '.'],
#  ['Girl', ':', 'Oh', 'yes', ',', 'you', 'do', '.'],
#  ['Girl', ':', '-', 'toned', ',', 'so', 'much', '.'],
#  ['Guy', '#', '2', ':', 'Yeah', ',', 'man', '.'],
#  ['ROBIN', ':', 'No', '.'],
#  ['Girl', '#', '1', ':', 'No', '.'],
#  ['She', "'", 's', 'just', 'a', 'bit', '.'],
#  ['What', 'are', 'you', 'talking', 'about', '?'],
#  ['I', 'thought', 'we', 'were', 'a', 'bit', 'more', '.'],
#  ['Guy', ':', 'Is', 'that', 'way', '?'],
#  ['Oh', ',', 'my', 'god', '.'],
#  ['Guy', ':', 'What', 'is', 'your', 'quest', '?'],
#  ['Girl', '#', '1', 'the', 'closing', 'doors', '.'],
#  ['Guy', ':', 'So', 'now', '?'],
#  ['Girl', '#', '1', ':', "'", 'm', 'single', '-'],
#  ['Hipster', 'girl', '#', '1', ':', 'Oooh', '.'],
#  ['No', 'thanks', '.'],
#  ['That', "'", 's', 'a', 'gay', '.'],
#  ['Teen', 'boy', ':', 'That', "'", 's', 'right', '.'],
#  ['I', 'should', 'sell', 'the', ',', 'though', '.'],
#  ['You', "'", 're', 'out', 'of', 'your', 'hand', '.'],
#  ['Guy', ':', ',', 'I', 'don', "'"],
#  ['He', "'", 'him', ',', 'on', 'the', 'URL', '.'],
#  ['Girl', '#', '1', ',', 'but', 'fine', '.'],
#  ['Girl', '#', '1', '.'],
#  ['Do', 'you', 'see', 'the', 'URL', 'on', 'him', '?'],
#  ['Woman', '#', '1', ':', 'No', '.'],
#  ['Hello', '.'],
#  ['Woman', '#', '2', ':', 'Wow', '.'],
#  ['Security', 'guy', ':', 'I', 'made', 'that', '.'],
#  ['Chick', ':', 'That', 'would', 'be', 'a', '.'],
#  ['Guy', ':', ',', 'I', "'", 'work', '!'],
#  ['It', 'was', 'fucking', 'bitch', ',', 'man', '.'],
#  ['Guy', ':', '.'],
#  ['Girl', '#', '2', '[', 'silence', ']'],
#  ['Why', 'am', 'I', ',', 'like', ',', 'I', '?'],
#  ['I', "'", 'm', 'not', 'so', 'much', '.'],
#  ['Girl', ':', 'Ummm', '...'],
#  ['Guy', '#', '2', ':', 'Ew', '.'],
#  ['Guy', ':', '.'],
#  ['That', "'", "'", 's', 'not', '.'],
#  ['Are', 'you', 'telling', 'the', 'same', '.'],
#  ['Girl', '#'],
#  ['It', "'", 'to', 'a', 'lot', 'of', 'people', '.'],
#  ['I', 'never', 'seen', 'any', 'of', 'them', '.'],
#  ['Not', 'much', '.', 'o', '.'],
#  ['****', 'A', 'good', 'wine', 'in', 'some', 'steps', '.'],
#  ['Did', 'you', 'hear', 'that', ',', 'eh', '?'],
#  ['Guy', ':', 'What', 'is', '.'],
#  ['Let', 'me', 'to', 'e', '.', '9', '.'],
#  ['Kid', "'", 's', 'father', ':', '.'],
#  ['She', 'doesn', "'", 't', 'read', '.'],
#  ['Nice', 'weight', 'on', 'the', 'mouth', '.'],
#  ['Ni', '!'],
#  ['I', 'you', 'want', 'money', 'or', 'a', 'bit', '?'],
#  ['Guy', ':', 'I', ',', 'no', '.'],
#  ['!'],
#  ['Girl', ':', 'Yeah', ','],
#  ['Guy', ':', 'What', ',', 'I', '?'],
#  ['Girl', ':', '.'],
#  ['Girl', ',', 'but', ',', 'I', 'have', 'a'],
#  ['Girl', '#', '1', ':', 'Yeah', '?'],
#  ['Little', 'boy', ':', 'I', 'am', 'the', 'Lord', '!'],
#  ['Girl', ',', 'I', '.'],
#  ['Guy', ':', 'But', 'he', 'say', '.'],
#  ['Guy', ':', '-', 'good', 'length', '.'],
#  ['I', "'", 't', 'keep', 'my', 'God', 'on', '...'],
#  ['Girl', '#', '2', '-', 'click', '.'],
#  ['Guy', ':', 'No', '.'],
#  ['Girl', '#', '2', ':', 'No', '!'],
#  ['**', 'Rich', ',', 'I', 'heard', 'that', 'a'],
#  ['You', 'go', 'and', 'walk', 'on', '.'],
#  ['Girl', 'on', 'very', 'good', 'for', 'a'],
#  ['Guy', ':', '.'],
#  ['At', 'least', '***(*)', 'Nice', 'fruit', '.'],
#  ['You', "'", 's', 'where', 'to', 'save', '.'],
#  ['Guy', ':', 'You', 'look', 'like', 'a', 'bit', '.'],
#  ['?'],
#  ['Bare', '***', 'Touch', 'of', 'the', 'same', '.'],
#  ['Guy', ':', 'You', 'should', 'be', 'a', 'lesbian', '.'],
#  ['Thank', 'you', "'"],
#  ['Girl', ':', 'I', "'", '.'],
#  ['Girl', ':', 'I', 'that', 'it', '!'],
#  ['Guy', ':', 'I', "'", 'back', 'on', 'what', '?'],
#  ['Girl', ':', 'Did', 'you', 'hear', 'that', 'one', '?'],
#  ['Girl', '#', '1', '.'],
#  ['Girl', ':', 'No', '.'],
#  ['Girl', '#', '1', ':', '!'],
#  ['Man', ':', 'You', 'mean', ',', '.'],
#  ['I', 'thought', 'he', 'had', 'a', "'", 's', '!'],
#  ['And', 'then', 'I', ',', 'it', '.'],
#  ['I', 'have', 'no', ',', 'right', 'now', '.'],
#  ['I', 'know', 'i', 'get', 'more', 'than', 'you', "'"],
#  ['Girl', '#', '2', 'a', 'good', 'drink', 'it', '.'],
#  ['FRENCH', 'GUARD', ':', 'I', "'", 'm', 'French', ','],
#  ['Girl', '#', '1', ':', 'No', '.'],
#  ['Girl', '#', '1', ':', 'man', '!'],
#  ['Girl', '#', '1', ':', 'I', "'", '.'],
#  ['That', "'", 's', 'a', 'night', '.'],
#  ['This', 'is', 'not', 'a'],
#  ['Good', '***', 'A', 'good', '***', 'A'],
#  ['Guy', '#', '1', '.'],
#  ['She', 'has', 'a', 'face', '.', '9', '.'],
#  ['I', 'don', "'", 't', 'wanna', 'know', 'you', '.'],
#  ['Suit', "'", 's', 'friend', ':', 'No', ','],
#  ['Girl', '#', '2', ':', 'Really', '?'],
#  ['I', "'", 's', 'called', 'me', 'and', 'a', '.'],
#  ['Guy', ':', "'", 's', 'next', '.', 'org', '/'],
#  ['I', "'", 't', 'that', "'", 't'],
#  ['Guy', ':', 'Damn', ',', 'girl', '!'],
#  ['****', 'Very', 'nice', ',', 'creamy', ',', 'lovely', '.'],
#  ['[', 'clang', ']', 'Bring', 'out', 'your', 'dead', '!'],
#  ['Girl', '#', '1', ':', 'Yeah', '!'],
#  ['Girl', '#', '2', ':', 'Not', 'yet', '.'],
#  ['Girl', ':', 'You', 'are', 'a', 'crazy', 'so', '.'],
#  ['Girl', '#', '2', ':', 'Sure', '.'],
#  ['Very', 'good', 'for', 'that', 'really', 'good', '.'],
#  ['Girl', '#', '1', ':', 'a', 'thousand', '!'],
#  ['Girl', '#', '1', ':', 'you', 'at', 'a'],
#  ['I', "'", 'e', '-', 'new', 'tab', '.'],
#  ['Guy', ':', '.'],
#  ['Guy', '#', '1', ':', 'You', 'know', 'her', '?'],
#  ['ARTHUR', ':', 'No', '!'],
#  ['Guy', ':', 'Don', "'", 't', 'touch', 'me', '.'],
#  ['Guy', ':', 'And', 'why', 'you', '?'],
#  ['Guy', ':', '.'],
#  ['Guy', ':', 'The', 'thing', ',', 'is', 'not', '!'],
#  ['Chick', ':', 'But', 'why', '?'],
#  ['Just', 'look', 'at', 'these', 'black', 'people', '!'],
#  ['She', 'was', 'a', 'bit', '.'],
#  ['Guy', ':', '.'],
#  ['Just', 'what', 'one', 'might', 'hope', 'for', 'o'],
#  ['I', "'", 'm', 'not', 'rich'],
#  ['Girl', '#', '1', '?'],
#  ['Man', ':', 'I', 'in', 'love', '?'],
#  ['I', 'mean', ',', 'fuck', 'it', '.'],
#  ['HEAD', 'KNIGHT', ':', 'Shh', '!'],
#  ['Why', 'did', 'you', 'to', 'break', 'up', '?'],
#  ['!'],
#  ['Guy', ':', '!'],
#  ['Ha', ',', 'ha', ',', 'ha', '!'],
#  ['**', 'A', 'good', 'and', 'nicely', 'structured', '.'],
#  ['Guy', ':', 'I', "'", 'about', 'at', 'night', '.'],
#  ['We', 'all', 'the', 'black', 'hair', '.'],
#  ['I', "'", 'm', 'going', 'in', 'that', 'good', '.'],
#  ['I', 'had', 'to', 'move', '.'],
#  ['Hello', '.'],
#  ['ELIZABETH', 'SWANN', ':', 'Will', '?'],
#  ['***(*)'],
#  ['Girl', '#'],
#  ['That', "'", 's', 'going', 'on', '?'],
#  ['I', "'", 'll', 'ask', 'him', 'at', 'the', '.'],
#  ['You', 'think', 'I', 'won', "'", 't', '?'],
#  ['Not', 'Rated', 'Very', 'pure', '.'],
#  ['Girl', '#', '1', ':', 'Hey', '!'],
#  ['Girl', '#'],
#  ['Girl', '#', '1', ':', '.'],
#  ['You', 'got', 'a', 'map', '?'],
#  ['Very', 'nice', '.'],
#  ['Teen', 'girl', '#', '1', ':', 'Of', 'course', '.'],
#  ['Girl', ':', 'What', "'", 'is', 'that', '?'],
#  ['Teen', 'girl', ':', 'Oh', 'my', 'god', '.'],
#  ['Guy', ':', '-', 'very', 'good', '***', 'A'],
#  ['Guy', ':', 'I', 'am', ',', 'thank', 'you', '.'],
#  ['I', 'really', 'a', 'bit', 'on', 'this', 'showing', '.'],
#  ['I', 'would', 'have', 'to', 'be', '.'],
#  ['Dude', ':', '1', ':', 'I', 'can', 'tell', '.'],
#  ['Teen', 'girl', ':', 'I', "'", 's', 'a'],
#  ['You', 'know', 'what', 'I', 'am', 'going', '?'],
#  ['Guy', ':', ',', 'a', 'quarter', '!'],
#  ['Girl', '#'],
#  ['Girl', '#', '2', ':', 'No', '?'],
#  ['Remember', 'that', "'", 't'],
#  ['Guy', ':', '.'],
#  ['Guy', ':', 'Is', 'that', 'fucking', 'bitch', '?'],
#  ['Guy', '#', '1', ':', 'Yeah', '.'],
#  ['They', "'", 're', 'not', '!'],
#  ['What', 'do', 'you', 'want', 'to', 'that', '?'],
#  ['Girl', ',', 'nuts', '.'],
#  ['From', 'a', 'lot', '.'],
#  ['Guy', ':', '.'],
#  ['I', "'", 'm', 'good', 'with', 'it', '.'],
#  ['Girl', '#'],
#  ['[', 'pause', ']', 'Black', 'lady', '.'],
#  ['Woman', ':', 'Wow', '!'],
#  ['Girl', '#', '1'],
#  ['Because', 'I', 'believe', 'in', 'God', '.'],
#  ['I', 'hope', 'this', 'is', 'an', 'odd', 'bottle', '.'],
#  ['Then', 'we', 'got', 'more', '.', 'js', 'seem', 'to'],
#  ['Girl', ':', 'You', 'can', 'have', 'my', 'life', '.'],
#  ['Guy', '#', '2', ':', 'No', '?'],
#  ['Girl', ':', 'Get', 'back', '.'],
#  ['What', 'kind', 'of', 'is', 'that', '?'],
#  ['Old', 'man', ':', 'What', '?'],
#  ['I', 'feel', 'sick', '.'],
#  ['Girl', '#'],
#  ['Girl', '#', '2', ':', 'Ugh', ',', 'gross', '.'],
#  ['What', 'do', 'you', 'mean', 'to', 'go'],
#  ['Southern', 'woman', ':', 'Oh', '!'],
#  ['Guy', '#', '1', 'on', 'the', 'middle', '.'],
#  ['Guy', ':', 'Yeah', '.'],
#  ['It', "'", 's', 'not', 'be', 'great', '.'],
#  ['Hobo', ':', 'Do', 'you', 'have', 'the', 'time', '?'],
#  ['Good', 'balance', 'and', 'wine', '.'],
#  ['Girl', '#', '1', ':', '!'],
#  ['I', 'am', 'I', '.'],
#  ['They', 'go', 'back', 'with', 'your', 'ass', '.'],
#  ['Girl', '#', '1', ':', 'What', '?'],
#  ['Guy', ':', 'Yes', '.'],
#  ['Guy', '#', '1', ':', '.'],
#  ['WILL', 'TURNER', ':', 'The', 'word', 'to', 'cum', '!'],
#  ['Teen', 'girl', ':', 'What', '?'],
#  ['Guy', ':', ',', 'I', '.'],
#  ['Girl', ':', 'Fuck', 'you', '.'],
#  ['Girl', '#', '1', ':', '.'],
#  ['Girl', '#', '1', ':'],
#  ['I', 'read', 'the', 'Bible', '.'],
#  ['Lovely', ',', 'will', 'be', 'great', '.'],
#  ['Guy', '#', '1', ':', 'Thanks', '.'],
#  ['***'],
#  ['Hipster', 'girl', ':', 'You', 'will', 'be', 'a', '.'],
#  ['Dad', '.'],
#  ['Guy', 'on', 'cell', ':', 'What', '?'],
#  ['We', 'have', 'to', 'us', 'off', 'the', 'ship', '.'],
#  ['Store', 'chick', ':', 'And', '?'],
#  ['Girl', '#', '1', ':', 'Yeah', ','],
#  ['Rather', 'good', '.'],
#  ['Girl', '#'],
#  ['ARTHUR', ':', 'No', '.'],
#  ['And', 'that', 'was', 'the', 'last', 'one', '.'],
#  ['Soft', '.'],
#  ['Top', '***', 'Very', 'fine', '.'],
#  ['Girl', '#'],
#  ['Guy', '?'],
#  ['***', 'Slightly', 'flat', '.'],
#  ['Girl', '#', '1', ':', 'No', '.'],
#  ['Girl', ':', 'on', 'the', 'palate', '.'],
#  ['***', 'A', 'bit', 'coarse', '.'],
#  ['Girl', ':', 'There', 'is', 'an', 'image', 'blocking', '"'],
#  ['Girl', ':', 'Well', 'that', 'was', 'like', '.'],
#  ['Guy', ':', 'I', 'know', ',', 'right', '?'],
#  ['I', 'mean', ',', 'nice', 'day', '.'],
#  ['Guy', ':', 'You', 'are', '?'],
#  ['Girl', '#'],
#  ['I', "'", 'S', ',', 'must', 'be', 'a', '"'],
#  ['***'],
#  ['I', "'", 's', 'very', 'good', '.'],
#  ['Guy', 'on', 'cell', ':', 'If', 'his', 'head', '.'],
#  ['Guy', '#', '1', ':', 'No', '...', 'Really', '?'],
#  ['Very', 'lovely', '.'],
#  ['Tourist', 'dad', ':', 'No', ',', '?'],
#  ['Girl', '#', '1', ':', ',', 'but', 'he', "'"],
#  ['Teen', 'boy', ':', 'No', '!'],
#  ['She', "'", 's', 'a', '!'],
#  ['Woman', ':', 'You', 'are', 'tight', '!'],
#  ['Girl', ',', 'dry', ',', 'long', '.'],
#  ['Bare', '***', 'Rather', 'good', 's'],
#  ['Girl', ':', 'We', 'have', 'this', 'huge', 'fat', '.'],
#  ['Girl', '#', '1', ':', '.'],
#  ['You', "'", 've', 'run', 'on', 'a'],
#  ['Guy', '.'],
#  ['Girl', ',', 'there', 'goes', 'my', 'god', ',', '.'],
#  ['Guy', '?'],
#  ['Girl', '#', '1', ':', '.'],
#  ['Girl', '#', '1'],
#  ['It', "'", 's', 'like', 'a', '.'],
#  ['Girl', '#', '1', ':', 'girl'],
#  ['Girl', '#', '1', '.'],
#  ['Girl', ':', 'But', '?'],
#  ['Girl', ':', 'Let', 'me', 'look', '.'],
#  ['Guy', ':', 'Oh', ',', 'no', '.'],
#  ['[', 'in', '.'],
#  ['Girl', '#', '1', ':'],
#  ['The', '"', 'is', '.'],
#  ['Girl', '#'],
#  ['Jack', 'Sparrow', '!'],
#  ['Guy', '#', '2', 'just', 'like', 'a', '.'],
#  ['Guy', ':', 'man', ':', 'Jesus', '.', '9'],
#  ['No', 'no', '!'],
#  ['I', 'never', 'seen', '.'],
#  ['White', 'girl', ':', 'We', 'are', 'from', 'the', '.'],
#  ['Hobo', 'lady', 'leaves', 'the', 'car', '.'],
#  ['Maybe', 'you', 'a', 'lot', 'better', 'if', 'this', '?'],
#  ['Guy', ':', '.'],
#  ['Girl', '#'],
#  ['Guy', '#', '1', '?'],
#  ['I', "'", 'm', 'not', 'a'],
#  ['Guy', ':', '!'],
#  ['Teen', 'boy', '#', '2', ':', 'No', '.'],
#  ['Guy', ':', 'Why', 'do', 'they', ',', 'right', '?'],
#  ['Girl', 'on', 'something', '?'],
#  ['Girl', ':', 'my', 'god', ',', 'I', 'was', '.'],
#  ['Pleasant', '.'],
#  ['I', "'", "'", 'em', 'in', 'a'],
#  ['This', 'is', 'New', 'York', ',', 'you', 'know', '?'],
#  ['Bare', '***(*)'],
#  ['A', 'bit', 'more', '.'],
#  ['Girl', '#', '1', ':', 'I'],
#  ['Burn', '!'],
#  ['What', "'", 's', 'wrong', 'with', 'her', '!'],
#  ['Hello', '.'],
#  ['Guy', ':', 'Dude', '.'],
#  ['Girl', '#', '1', ':', 'it', 'together', '?'],
#  ['Girl', '#', '2', ':', 'No', '?'],
#  ['Girl', '#', '1', ':', 'The', 'Black', 'Pearl', '?'],
#  ['Guy', '.'],
#  ['.'],
#  ['Girl', '#', '2', 'a', 'bit', 'of', 'the', '.'],
#  ['Girl', '#', '2', ':', 'Uh', 'huh', '.'],
#  ['Girl', '#', '1', ':', 'Move', 'it', '.'],
#  ['Who', 'lives', 'in', 'that', 'castle', '!'],
#  ['That', "'", 't', '?'],
#  ['Guy', ':', '!'],
#  ['You', 'had', 'to', 'be', 'a', 'much', '.'],
#  ['The', 'children', '!'],
#  ['Is', 'that', "'", 'it', "'", 's', 'called', '?'],
#  ['DINGO', ':', 'Oh', ',', 'yes', '.'],
#  ['Quite', 'rich', '-', 'toned', '.'],
#  ['Girl', ':', '.'],
#  ['Girl', '#', '1', ':'],
#  ['You', 'have', 'kids', '!'],
#  ['I', "'", '&', 'T'],
#  ['Little', 'girl', 'in', 'the', 'URL', ':', 'Hey', '!'],
#  ['?'],
#  ['Guy', ':', ',', 'but', 'I', 'really', '?'],
#  ['So', ',', 'I', 'built', 'a', 'second', 'on', '.'],
#  ['That', "'", 's', 'up', '?'],
#  ['I', 'am', 'a', 'bit', '.'],
#  ['Girl', '#'],
#  ['Guy', ':', '.'],
#  ['Girl', '#', '1', ':', ',', 'I', '.'],
#  ['Girl', '#'],
#  ['Guy', ':', 'And', 'you', 'still', 'hit', 'that', '?'],
#  ['Girl', '#', '1', ':', 'Really', 'good', 'acidity', '.'],
#  ['Girl', ',', 'it', "'", 's', 'father', 'is', '.'],
#  ['Thank', 'you', 'for', 'your', 'ass', '.'],
#  ['ARTHUR', ':', 'Run', 'away', '!'],
#  ['You', 'look', 'like', '.'],
#  ['Girl', '#', '2', ':', 'What', '?'],
#  ['Guy', ':', 'this', '.'],
#  ['Girl', '#', '1', ':', ',', 'shit', '.'],
#  ['Girl', '#', '1', ':', 'not', '?'],
#  ['Girl', ',', 'but', ',', 'a', 'bit', 'more', '.'],
#  ['Top', '***'],
#  ['Guy', ':', 'S', '/', 'S', '/', 'S'],
#  ['Guy', '#', '2', ':', 'No', '!'],
#  ['Guy', ':', 'Are', 'you', 'kidding', 'me', '?'],
#  ['Guy', ':', '.'],
#  ['You', 'are', 'the', 'one', 'who', 'wants', 'to', '!'],
#  ['I', 'was', 'pissed', '.', '9', '.'],
#  ['I', "'", 's', 'a', 'good', 'guy', '.'],
#  ['Girl', ':', 'in', 'the', 'next', 'few', 'years', '.'],
#  ['It', "'", 's', '*', 'No', ','],
#  ['I', "'", 's', 'her', 'again', '!'],
#  ['Girl', ':', 'Where', "'", 's', 'the', 'bathroom', '?'],
#  ['Girl', ':', 'Camelot', '!'],
#  ['Guy', '#', '1', ':', 'No', '.'],
#  ['Very', 'good', 'and', 'will', 'be', 'lovely', '.'],
#  ['***', 'Slightly', 'flat', ',', 'I', '.'],
#  ['Guy', ':', '...', 'I', '.'],
#  ['Girl', ':', 'Where', 'are', 'you', 'going', '?'],
#  ['Girl', '#', '1', ',', 'though', '.'],
#  ['Guy', '#', '1', ':', 'Hey', '.'],
#  ['Girl', '#', '1', ':', 'There', "'", 's', 'a'],
#  ['Girl', '#'],
#  ['Girl', '#', '1', ':', ',', 'I', '.'],
#  ['Girl', '#'],
#  ['Girl', '#', '1', ':', 'Right', ',', 'I', '?'],
#  ['Is', 'this', 'the', 'same', 'as', 'the', 'Avenue', '?'],
#  ['Girl', '#'],
#  ['Girl', ':', 'No', 'way', '!'],
#  ['So', ',', 'now', 'that', '?'],
#  ['Girl', '#', '2', ':', 'I', 'was', '?'],
#  ['Girl', '#', '2', ':', 'Hey', ',', 'i'],
#  ['Girl', ':', ',', 'dry', 'long', '.'],
#  ['Ah', '!'],
#  ['You', 'mean', 'they', "'", 'out', 'of', 'the', '"'],
#  ['Guy', '.'],
#  ['Girl', '#', '1', ':'],
#  ['Girl', '#', '1', ':', 'It', "'", '.'],
#  ['Guy', ':', 'Are', 'we', 'in', 'the', '"'],
#  ['Guy', ':', 'The', '6', 'train', '!'],
#  ['Girl', ':', 'It', "'", 's', 'not', 'sure', '.'],
#  ['Girl', ':', '.'],
#  ['Chick', ':', 'I', 'need', 'my', 'god', '.'],
#  ['I', "'", 'or', 'something', 'called', '?'],
#  ['Very', 'good', '.'],
#  ['Girl', '#', '1', ',', 'I', "'", '.'],
#  ['Little', 'girl', ':', 'I', 'did', ',', 'Mom', '.'],
#  ['Girl', ':', 'I', "'", 's', 'real', '.'],
#  ['Guy', ':', 'Do', 'you', 'have', 'names', 'and', 'I'],
#  ['Is', 'that', 'make', 'you', '?'],
#  ['Guy', ':', 'So', 'you', 'were', 'so', 'then', '?'],
#  ['No', '.'],
#  ['It', "'", 's', 'like', 'the', 'same', '.'],
#  ['And', 'I', 'was', 'like', ',', '"', 'in', '?'],
#  ['Oh', '.'],
#  ['Black', 'teen', ':', 'I', 'be', 'trying', '"'],
#  ['That', "'", 's', 'just', 'won', '.'],
#  ['Girl', '#', '2', 'Really', '?'],
#  ['What', 'do', 'I', 'give', 'a', 'fuck', '?'],
#  ['Girl', ':', 'Yeah', ',', 'I', 'know', '.'],
#  ['Guy', ':', '?'],
#  ['Guy', ':', 'white', 'people', 'are', '.'],
#  ['Guy', ':', 'Ni', '!'],
#  ['Girl', '#', '2', ':', 'No', ',', '!'],
#  ['Guy', ':', '.'],
#  ['Guy', ':', 'A', 'bit', '?'],
#  ['[', 'pause', ']', '[', 'a'],
#  ['Have', 'a', 'good', 'day', '.'],
#  ['Girl', '#', '1', ':', 's'],
#  ['Frat', 'boy', ':', 'Wow', '!'],
#  ['Guy', '.'],
#  ['Girl', ':', 'Uh', ',', 'no', 'thanks', '.', '9'],
#  ['I', 'know', '.'],
#  ['Oh', 'man', ',', 'I', "'", '!'],
#  ['Guy', ':', '.'],
#  ['Guy', ':', '.'],
#  ['Girl', ':', 'Do', 'you', 'know', 'your', 'ass', '?'],
#  ['Guy', ':', '?'],
#  ['What', 'are', 'you', 'talking', 'about', '?'],
#  ['Very', 'pleasant', '.'],
#  ['Guy', 'with', 'a', 'bit', 'on', 'his', 'face', '.'],
#  ['BLACK', 'KNIGHT', ':', 'Have', 'I', 'you', '!'],
#  ['Chick', ':', 'Oh', '.'],
#  ['Girl', '#', '1', ':'],
#  ['Not', 'a', 'style', 'I', 'know', '.'],
#  ['I', 'said', 'it', 'a'],
#  ['A', 'witch', '!'],
#  ['Teen', 'boy', ':', '?'],
#  ['Guy', ':', 'Is', 'that', 'really', 'isn', "'", 't'],
#  ['That', 'lady', 'is', 'a', 'of', '?'],
#  ['Man', ':', 'They', 'just', 'anyone', '.'],
#  ['It', "'", 's', 'really', 'good', '.'],
#  ['What', 'happened', '?'],
#  ['Guy', '#', '1', ':', 'No', 'such', 'as', 'a'],
#  ['Guy', ':', 'You', 'see', '?'],
#  ['Cashier', 'chick', '#', '1', ':', 'Oh', 'no', '.'],
#  ['Old', 'man', 'and', 'all', 'that', '.'],
#  ['Ni', '!'],
#  ['ELIZABETH', 'SWANN', ':', 'No', '.'],
#  ['Girl', '...', 'No', '-', 'something', '.'],
#  ['You', 'want', 'a', 'joke', '?'],
#  ['Like', 'a', 'new', 'tab', '.'],
#  ['Girl', '#', '1', ':', '!'],
#  ['Guy', '.'],
#  ['Girl', ':', 'Oh', ',', 'please', '.'],
#  ['Guy', ':', ',', 'floral', ',', 'rich', 'fruit', '.'],
#  ['I', "'", '.'],
#  ['...', 'TIM', ':', 'Ha', 'ha', 'ha', 'ha', '!'],
#  ['Ha', ',', 'ha', '.'],
#  ['ARTHUR', ':', 'Good', 'wine', ',', 'O', 'Lord', '!'],
#  ['Girl', 'on', '?'],
#  ['I', 'gave', 'you', 'know', '?'],
#  ['Guy', ':', '.'],
#  ['I', 'love', 'you', ',', 'Mom', '.'],
#  ['Girl', '#', '1', ':', 'I', "'", 't', '.'],
#  ['Bare', '***'],
#  ['Guy', '#', '1', ':', 'Yeah', '.'],
#  ['Guy', ':', '!'],
#  ['You', 'can', "'", 't', 'believe', 'it', '.'],
#  ['Girl', ':', 'I', 'just', 'like', 'and', 'like', '.'],
#  ['Girl', '...', 'to', 'hang', 'with', 'the', 'time', '?'],
#  ['Have', 'you', "'", 's', 'as', 'your', 'ass', '.'],
#  ['Old', 'man', '#', '1', ':', 'White', 'girl', '.'],
#  ['Burn', 'her', '!'],
#  ['Guy', ':', 'That', "'", 's', 'a', '!'],
#  ['He', "'", 's', 'fat', '.'],
#  ['Girl', '#', '1', '/', 'ship', '!'],
#  ['**', 'A', ',', 'but', ',', 'but', 'not', '.'],
#  ['Guy', '#', '2', ':', 'About', '"', 'minutes', '?'],
#  ['I', "'", 'm', 'not', 'work', 'and', '!'],
#  ['Girl', ':', 'You', 'really', 'think', 'so', '?'],
#  ['[', 'a', 'lot', 'of', 'you', 'for', 'that', '!'],
#  ['Girl', 'with', 'us', 'to', 'be', '.'],
#  ['**', 'Pleasant', '.'],
#  ['Girl', 'you', 'talking', 'about', '?'],
#  ['Do', 'you', 'mean', 'a', "'", 't', '?'],
#  ['Girl', ':', 'Is', 'that', 'a', 'new', '-'],
#  ['Guy', ':', 'What', 'are', 'you', 'doing', '?'],
#  ['I', 'feel', 'like', ',', 'i'],
#  ['Top', '***', 'Lovely', ',', 'but', 'it', '.'],
#  [],
#  ...]

# %%
import jiwer

total_wer = 0
total_cer = 0
total_sentences = len(filtered_texts)

for original, corrected_sentence in zip(filtered_texts[:len(filtered_texts)], corrected):
    
    original = ' '.join(original)
    corrected_sentence = ' '.join(corrected_sentence)
    
    # Calculate Word Error Rate (WER)
    wer = jiwer.wer(original, corrected_sentence)
    total_wer += wer

    # Calculate Character Error Rate (CER)
    cer = jiwer.cer(original, corrected_sentence)
    total_cer += cer

avg_wer = total_wer / total_sentences
avg_cer = total_cer / total_sentences


print(f"Average Word Error Rate (WER): {avg_wer * 100:.2f}%")
print(f"Average Character Error Rate (CER): {avg_cer * 100:.2f}%")
# Out:
# Average Word Error Rate (WER): 34.13%
# Average Character Error Rate (CER): 32.19%
